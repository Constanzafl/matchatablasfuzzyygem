# %%
#instalo/actualizo
#! pip3 install --upgrade google-cloud-aiplatform

# %%
import re
import pandas as pd
from google.cloud import bigquery
import vertexai 
from vertexai.generative_models import GenerationConfig, GenerativeModel, Image, Part, Content
import vertexai.preview.generative_models as generative_models 
import sys
import os
from fuzzywuzzy import process, fuzz

# %%
import os 
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:\\Users\\flori\\OneDrive\\Desktop\\LDP\\ldp-data-genai-producto-b871ebffc681.json"

# %%
##curso...pongo el id del proyecto del gcp de prueba q inicie con este mail
# Define project information
PROJECT_ID = "ldp-data-genai-producto"  # @param {type:"string"}
LOCATION = "us-central1"  # @param {type:"string"}

# Initialize Vertex AI
import vertexai

vertexai.init(project=PROJECT_ID, location=LOCATION)

# %%
# Crear un cliente de BigQuery con el proyecto especificado
client = bigquery.Client(project='ldp-data-wyscout')
model = GenerativeModel("gemini-1.5-flash-002")
model2= GenerativeModel("gemini-1.5-pro-001")

# %%
generation_config = GenerationConfig(
    temperature=0,
    top_p=0.0,
    top_k=1,
    candidate_count=1,
    max_output_tokens=8192,
)

# %%
safety_settings = {
    generative_models.HarmCategory.HARM_CATEGORY_HATE_SPEECH: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    generative_models.HarmCategory.HARM_CATEGORY_HARASSMENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
}

# %%
# Consulta SQL
query2 = """select t.player_id, w.wy_id, t.* from ldp-data-wyscout.transfer_market.players_transfers_curated t
left join ldp-data-wyscout.transfer_market.matching_playerids_v4 w on safe_cast(t.player_id as int)=w.tm_id ;"""

try:
    # Ejecutar la consulta y obtener los resultados en un DataFrame
    df1 = client.query(query2).to_dataframe()
    print(df1.head())
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#   player_id  wy_id row_ind      player_name season transfer_date  \
# 0     91280  16081       7     Boné Uaferro  03/04    2003-07-01
# 1     41323   <NA>       8    Andreas Luthe  04/05    2004-07-01
# 2     26171   <NA>      10  Mike Wunderlich  04/05    2004-07-01
# 3     26171   <NA>       9  Mike Wunderlich  05/06    2005-07-01
# 4    160968  18544       8    Benno Schmitz  01/02    2001-07-01
#
#         team_from          team_to market_value transfer_value  \
# 0  Altglien. Jgd.   U. Berlin Yth.           NA              0
# 1  VfL Bochum U17   VfL Bochum U19           NA             NA
# 2  Vikt. Köln U19    1.FC Köln U19           NA             NA
# 3   1.FC Köln U19     1.FC Köln II           NA             NA
# 4  Waldperl. Yth.  B. München Yth.           NA              0
#
#   contract_expiry                                         player_url  \
# 0              NA  https://www.transfermarkt.com/bone-uaferro/pro...
# 1              NA  https://www.transfermarkt.com/andreas-luthe/pr...
# 2              NA  https://www.transfermarkt.com/mike-wunderlich/...
# 3              NA  https://www.transfermarkt.com/mike-wunderlich/...
# 4              NA  https://www.transfermarkt.com/benno-schmitz/pr...
#
#    query_date                 timestamp  \
# 0  2024-09-08 2024-09-07 14:27:45+00:00
# 1  2024-09-08 2024-09-07 14:27:45+00:00
# 2  2024-09-10 2024-09-07 14:31:16+00:00
# 3  2024-09-10 2024-09-07 14:31:16+00:00
# 4  2024-09-07 2024-09-07 14:27:45+00:00
#
#                                                 blob player_id_1  \
# 0  transfermarkt/player_transfers/ players_transf...       91280
# 1  transfermarkt/player_transfers/ players_transf...       41323
# 2  transfermarkt/player_transfers/ players_transf...       26171
# 3  transfermarkt/player_transfers/ players_transf...       26171
# 4  transfermarkt/player_transfers/ players_transf...      160968
#
#                                            teams_url team_id  \
# 0  https://www.transfermarkt.com/1-fc-saarbrucken...       1
# 1  https://www.transfermarkt.com/1-fc-kaiserslaut...       2
# 2  https://www.transfermarkt.com/1-fc-kaiserslaut...       2
# 3  https://www.transfermarkt.com/1-fc-kaiserslaut...       2
# 4  https://www.transfermarkt.com/1-fc-koln/starts...       3
#
#   player_transfer_id
# 0     20030701191280
# 1     20040701241323
# 2     20040701226171
# 3     20050701226171
# 4    200107013160968

# %%
df1.head()
# Out:
#   player_id  wy_id row_ind      player_name season transfer_date  \
# 0     91280  16081       7     Boné Uaferro  03/04    2003-07-01
# 1     41323   <NA>       8    Andreas Luthe  04/05    2004-07-01
# 2     26171   <NA>      10  Mike Wunderlich  04/05    2004-07-01
# 3     26171   <NA>       9  Mike Wunderlich  05/06    2005-07-01
# 4    160968  18544       8    Benno Schmitz  01/02    2001-07-01
#
#         team_from          team_to market_value transfer_value  \
# 0  Altglien. Jgd.   U. Berlin Yth.           NA              0
# 1  VfL Bochum U17   VfL Bochum U19           NA             NA
# 2  Vikt. Köln U19    1.FC Köln U19           NA             NA
# 3   1.FC Köln U19     1.FC Köln II           NA             NA
# 4  Waldperl. Yth.  B. München Yth.           NA              0
#
#   contract_expiry                                         player_url  \
# 0              NA  https://www.transfermarkt.com/bone-uaferro/pro...
# 1              NA  https://www.transfermarkt.com/andreas-luthe/pr...
# 2              NA  https://www.transfermarkt.com/mike-wunderlich/...
# 3              NA  https://www.transfermarkt.com/mike-wunderlich/...
# 4              NA  https://www.transfermarkt.com/benno-schmitz/pr...
#
#    query_date                 timestamp  \
# 0  2024-09-08 2024-09-07 14:27:45+00:00
# 1  2024-09-08 2024-09-07 14:27:45+00:00
# 2  2024-09-10 2024-09-07 14:31:16+00:00
# 3  2024-09-10 2024-09-07 14:31:16+00:00
# 4  2024-09-07 2024-09-07 14:27:45+00:00
#
#                                                 blob player_id_1  \
# 0  transfermarkt/player_transfers/ players_transf...       91280
# 1  transfermarkt/player_transfers/ players_transf...       41323
# 2  transfermarkt/player_transfers/ players_transf...       26171
# 3  transfermarkt/player_transfers/ players_transf...       26171
# 4  transfermarkt/player_transfers/ players_transf...      160968
#
#                                            teams_url team_id  \
# 0  https://www.transfermarkt.com/1-fc-saarbrucken...       1
# 1  https://www.transfermarkt.com/1-fc-kaiserslaut...       2
# 2  https://www.transfermarkt.com/1-fc-kaiserslaut...       2
# 3  https://www.transfermarkt.com/1-fc-kaiserslaut...       2
# 4  https://www.transfermarkt.com/1-fc-koln/starts...       3
#
#   player_transfer_id
# 0     20030701191280
# 1     20040701241323
# 2     20040701226171
# 3     20050701226171
# 4    200107013160968

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104606 entries, 0 to 1104605
# Data columns (total 19 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   player_id           1104605 non-null  object
#  1   wy_id               579565 non-null   Int64
#  2   row_ind             1104606 non-null  object
#  3   player_name         1104606 non-null  object
#  4   season              1104606 non-null  object
#  5   transfer_date       1104606 non-null  object
#  6   team_from           1104606 non-null  object
#  7   team_to             1104606 non-null  object
#  8   market_value        1104606 non-null  object
#  9   transfer_value      1104606 non-null  object
#  10  contract_expiry     1104606 non-null  object
#  11  player_url          1104606 non-null  object
#  12  query_date          1104606 non-null  dbdate
#  13  timestamp           1104606 non-null  datetime64[us, UTC]
#  14  blob                1007016 non-null  object
#  15  player_id_1         1104605 non-null  object
#  16  teams_url           1104605 non-null  object
#  17  team_id             1104605 non-null  object
#  18  player_transfer_id  1104605 non-null  object
# dtypes: Int64(1), datetime64[us, UTC](1), dbdate(1), object(16)
# memory usage: 161.2+ MB

# %%
dftext = df1.to_csv(index=False)

# %%
###ME TRAIGO LOS DATOS DE LA TABLA DE CAPOLOGY
query = """select w.playerId, t.tm_id, w.* from ldp-data-wyscout.wyscout_curated.transfer_con_nombre w
left join ldp-data-wyscout.transfer_market.matching_playerids_v4 t on w.playerId=t.wy_id;
 """

try:
    # Ejecutar la consulta y obtener los resultados en un DataFrame                     ###domestic_competition_name
    df2 = client.query(query).to_dataframe()
    print(df2.head())
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#    playerId  tm_id                    nombre  transferId  fromTeamId  \
# 0   1061989   <NA>  Hákon Atli Aðalsteinsson     2252367        7724
# 1   1061951   <NA>                 Zen Galea     2252155        <NA>
# 2   1061960   <NA>            Daniel Radeski     2252179        <NA>
# 3   1061902   <NA>            Sanel Ibisevic     2251976       34765
# 4   1061905   <NA>     Hassan Mushtaq Taheri     2252004        7060
#
#            fromTeamName  toTeamId             toTeamName active   startDate  \
# 0           KA Akureyri      7749              Völsungur      0  2023-04-06
# 1                            <NA>        Mgarr United FC      0  2024-03-01
# 2                            8380  Stirling Macedonia SC      0  2024-03-01
# 3  TSV Havelse Under 19      7143               Follo FK      0  2018-09-04
# 4          Boo FF Nacka      7143               Follo FK      0  2022-09-08
#
#       endDate      type value currency announceDate  playerId_1
# 0  2024-02-02      Loan     0      EUR                  1061989
# 1        None   Unknown     0      EUR                  1061951
# 2        None   Unknown     0      EUR                  1061960
# 3        None  Transfer     0      EUR                  1061902
# 4        None  Transfer     0      EUR                  1061905

# %%
df2.head(20)
# Out:
#     playerId  tm_id                                 nombre  transferId  \
# 0    1061989   <NA>               Hákon Atli Aðalsteinsson     2252367
# 1    1061951   <NA>                              Zen Galea     2252155
# 2    1061960   <NA>                         Daniel Radeski     2252179
# 3    1061902   <NA>                         Sanel Ibisevic     2251976
# 4    1061905   <NA>                  Hassan Mushtaq Taheri     2252004
# 5    1061911   <NA>                    Hans Kristian Heier     2252032
# 6    1061921   <NA>                    Herman Oen Paulsrud     2252070
# 7    1061847   <NA>                          Lucas Poulsen     2352906
# 8    1061847   <NA>                          Lucas Poulsen     2251604
# 9    1061985   <NA>                     Kasper Sommerstedt     2408653
# 10   1061932   <NA>                           Osama Housni     2252131
# 11   1061976   <NA>                           Ahmad Shaban     2376923
# 12   1061989   <NA>               Hákon Atli Aðalsteinsson     2364280
# 13   1061901   <NA>                        Marco Rodrigues     2251956
# 14   1061911   <NA>                    Hans Kristian Heier     2252031
# 15   1061921   <NA>                    Herman Oen Paulsrud     2252078
# 16   1061902   <NA>                         Sanel Ibisevic     2251975
# 17   1061786   <NA>                      Dominik Petrovčin     2401863
# 18   1061851   <NA>                            Leon Graham     2351286
# 19   1061797   <NA>  Matias Inojosa Galindo Nunes Teixeira     2352901
#
#     fromTeamId             fromTeamName  toTeamId  \
# 0         7724              KA Akureyri      7749
# 1         <NA>                               <NA>
# 2         <NA>                               8380
# 3        34765     TSV Havelse Under 19      7143
# 4         7060             Boo FF Nacka      7143
# 5         7191         Lillestrøm SK II      7143
# 6        24654     Grorud Idrettslag II      7345
# 7         7463             BK Frem 1886     34555
# 8        34555                Sundby BK      7463
# 9        11173          ÍF Fuglafjørdur     22910
# 10        7292               Holmlia SK      7354
# 11       13294           Hapoel Acre FC     13364
# 12        7724              KA Akureyri      7809
# 13        7295               Skedsmo FK      7128
# 14        7133        Drøbak / Frogn IL      7191
# 15        7194        Stabæk Fotball II     24654
# 16        7352              Follo FK II     34765
# 17       24150     HNK Šibenik Under 19     34096
# 18       10860          Cliftonville FC      <NA>
# 19       31422  Gil Vicente FC Under 19      <NA>
#
#                         toTeamName active   startDate     endDate        type  \
# 0                        Völsungur      0  2023-04-06  2024-02-02        Loan
# 1                  Mgarr United FC      0  2024-03-01        None     Unknown
# 2            Stirling Macedonia SC      0  2024-03-01        None     Unknown
# 3                         Follo FK      0  2018-09-04        None    Transfer
# 4                         Follo FK      0  2022-09-08        None    Transfer
# 5                         Follo FK      0  2023-08-21        None    Transfer
# 6                        Grorud IL      0  2024-03-22        None    Transfer
# 7                        Sundby BK      0  2024-08-01        None    Transfer
# 8                     BK Frem 1886      0  2024-02-01  2024-06-30    Transfer
# 9                     Hedensted BK      0  2024-08-27        None    Transfer
# 10                   Nordstrand IF      0  2023-07-28  2024-03-05    Transfer
# 11                 Hapoel Afula FC      0  2024-07-01        None    Transfer
# 12                 Dalvík / Reynir      0  2024-08-01        None    Transfer
# 13                 Kjelsås Fotball      0  2024-03-18        None    Transfer
# 14                Lillestrøm SK II      0  2022-01-04  2023-08-21    Transfer
# 15            Grorud Idrettslag II      0  2022-06-29  2024-03-22    Transfer
# 16            TSV Havelse Under 19      0  2017-08-24  2018-09-04    Transfer
# 17  FC Internazionale Milano Under      0  2024-08-28        None    Transfer
# 18                            None      0  2024-06-30        None  Free Agent
# 19                            None      0  2024-06-30        None  Free Agent
#
#    value currency announceDate  playerId_1
# 0      0      EUR                  1061989
# 1      0      EUR                  1061951
# 2      0      EUR                  1061960
# 3      0      EUR                  1061902
# 4      0      EUR                  1061905
# 5      0      EUR                  1061911
# 6      0      EUR                  1061921
# 7      0      EUR                  1061847
# 8      0      EUR                  1061847
# 9      0      EUR                  1061985
# 10     0      EUR                  1061932
# 11     0      EUR                  1061976
# 12     0      EUR                  1061989
# 13     0      EUR                  1061901
# 14     0      EUR                  1061911
# 15     0      EUR                  1061921
# 16     0      EUR                  1061902
# 17     0      EUR                  1061786
# 18     0      EUR                  1061851
# 19     0      EUR                  1061797

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1933826 entries, 0 to 1933825
# Data columns (total 16 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   playerId      Int64
#  1   tm_id         Int64
#  2   nombre        object
#  3   transferId    Int64
#  4   fromTeamId    Int64
#  5   fromTeamName  object
#  6   toTeamId      Int64
#  7   toTeamName    object
#  8   active        object
#  9   startDate     object
#  10  endDate       object
#  11  type          object
#  12  value         object
#  13  currency      object
#  14  announceDate  object
#  15  playerId_1    Int64
# dtypes: Int64(6), object(10)
# memory usage: 247.1+ MB

# %%
#df1.dropna(inplace=True)

# %%
dftext2 = df2.to_csv(index=False)

# %%
query = """WITH tabla1 AS (
    -- Primera consulta: renombramos los playerId y tm_id para evitar ambigüedad
    SELECT w.playerId AS wy_playerId, t.tm_id AS tm_id, w.*
    FROM ldp-data-wyscout.wyscout_curated.transfer_con_nombre w
    LEFT JOIN ldp-data-wyscout.transfer_market.matching_playerids_v4 t 
    ON w.playerId = t.wy_id
),
tabla2 AS (
    -- Segunda consulta: renombramos los player_id y wy_id para evitar ambigüedad
    SELECT t.player_id AS tm_playerId, w.wy_id AS wy_id, t.*
    FROM ldp-data-wyscout.transfer_market.players_transfers_curated t
    LEFT JOIN ldp-data-wyscout.transfer_market.matching_playerids_v4 w 
    ON SAFE_CAST(t.player_id AS INT) = w.tm_id
)

-- Unir ambas tablas por los IDs correspondientes
SELECT  *
FROM tabla1
JOIN tabla2 
ON tabla1.wy_playerId = tabla2.wy_id 
  AND tabla1.tm_id =  SAFE_CAST(tabla2.tm_playerId AS INT);
 """

try:
    # Ejecutar la consulta y obtener los resultados en un DataFrame                     ###domestic_competition_name
    df3 = client.query(query).to_dataframe()
    print(df3.head())
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#    wy_playerId   tm_id                  nombre  transferId  fromTeamId  \
# 0       240902  104871    Martín Ariel Pucheta     1895516       12264
# 1       240902  104871    Martín Ariel Pucheta        6559       23216
# 2       240902  104871    Martín Ariel Pucheta      514314       17383
# 3       805662  976205  Daniel Atanes Rekelhof     2199128       39691
# 4       851642  701527     Jose  Barbosa Nhoca     1731386        <NA>
#
#                      fromTeamName  toTeamId                      toTeamName  \
# 0  Club Atlético Sarmiento de Res     12066     Club Olimpo de Bahía Blanca
# 1                  Andes Talleres     12132         Independiente Rivadavia
# 2                      CD Motagua     23214  Club Atlético San Lorenzo de A
# 3                      UD Montijo       731                  Rayo Cantabria
# 4                                        53                       Noordwijk
#
#   active   startDate  ... transfer_value contract_expiry  \
# 0      0  2023-01-05  ...              0              NA
# 1      0  2013-07-05  ...              0              NA
# 2      1  2017-07-01  ...              0              NA
# 3      0  2024-01-24  ...              0      2024-06-30
# 4      0  2022-07-01  ...              0              NA
#
#                                           player_url  query_date  \
# 0  https://www.transfermarkt.com/martin-pucheta/p...  2024-09-10
# 1  https://www.transfermarkt.com/martin-pucheta/p...  2024-09-10
# 2  https://www.transfermarkt.com/martin-pucheta/p...  2024-09-10
# 3  https://www.transfermarkt.com/dani-atanes/prof...  2024-09-11
# 4  https://www.transfermarkt.com/jose-barbosa-nho...  2024-09-11
#
#                   timestamp  \
# 0 2024-09-07 14:31:16+00:00
# 1 2024-09-07 14:31:16+00:00
# 2 2024-09-07 14:31:16+00:00
# 3 2024-09-07 14:27:45+00:00
# 4 2024-09-07 14:31:16+00:00
#
#                                                 blob player_id  \
# 0  transfermarkt/player_transfers/ players_transf...    104871
# 1  transfermarkt/player_transfers/ players_transf...    104871
# 2  transfermarkt/player_transfers/ players_transf...    104871
# 3  transfermarkt/player_transfers/ players_transf...    976205
# 4  transfermarkt/player_transfers/ players_transf...    701527
#
#                                            teams_url team_id  \
# 0  https://www.transfermarkt.com/club-olimpo/star...    7468
# 1  https://www.transfermarkt.com/club-olimpo/star...    7468
# 2  https://www.transfermarkt.com/club-olimpo/star...    7468
# 3  https://www.transfermarkt.com/vv-noordwijk/sta...    7474
# 4  https://www.transfermarkt.com/vv-noordwijk/sta...    7474
#
#    player_transfer_id
# 0  202107017468104871
# 1  202107017468104871
# 2  202107017468104871
# 3  202401247474976205
# 4  201807017474701527
#
# [5 rows x 35 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4560963 entries, 0 to 4560962
# Data columns (total 35 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   wy_playerId         Int64
#  1   tm_id               Int64
#  2   nombre              object
#  3   transferId          Int64
#  4   fromTeamId          Int64
#  5   fromTeamName        object
#  6   toTeamId            Int64
#  7   toTeamName          object
#  8   active              object
#  9   startDate           dbdate
#  10  endDate             dbdate
#  11  type                object
#  12  value               object
#  13  currency            object
#  14  announceDate        object
#  15  playerId            Int64
#  16  tm_playerId         object
#  17  wy_id               Int64
#  18  row_ind             object
#  19  player_name         object
#  20  season              object
#  21  transfer_date       object
#  22  team_from           object
#  23  team_to             object
#  24  market_value        object
#  25  transfer_value      object
#  26  contract_expiry     object
#  27  player_url          object
#  28  query_date          dbdate
#  29  timestamp           datetime64[us, UTC]
#  30  blob                object
#  31  player_id           object
#  32  teams_url           object
#  33  team_id             object
#  34  player_transfer_id  object
# dtypes: Int64(7), datetime64[us, UTC](1), dbdate(3), object(24)
# memory usage: 1.2+ GB

# %%
# Contar los valores nulos en cada columna
null_counts = df3.isnull().sum()

# Filtrar las columnas que tienen valores nulos
columns_with_nulls = null_counts[null_counts > 0]

print(columns_with_nulls)
# Out:
# fromTeamId      528665
# fromTeamName    329914
# toTeamId        213755
# toTeamName      163435
# startDate           97
# endDate         787223
# type                41
# currency           449
# blob            378597
# dtype: int64

# %%
# Obtener el rango de fechas en df3
fecha_inicio = df3['startDate'].min()
fecha_fin = df3['endDate'].max()

print(f"El rango de fechas en df3 es de {fecha_inicio} a {fecha_fin}")

# Verificar si hay valores repetidos en df3
valores_repetidos = df3.duplicated().sum()

print(f"El número de valores repetidos en df3 es: {valores_repetidos}")
# Out:
# El rango de fechas en df3 es de 1984-02-14 a 2030-06-30
# El número de valores repetidos en df3 es: 0

# %%
df4=df3.dropna()

# %%
df3.head(50)
# Out:
#     wy_playerId    tm_id                               nombre  transferId  \
# 0        240902   104871                 Martín Ariel Pucheta     1895516
# 1        240902   104871                 Martín Ariel Pucheta        6559
# 2        240902   104871                 Martín Ariel Pucheta      514314
# 3        805662   976205               Daniel Atanes Rekelhof     2199128
# 4        851642   701527                  Jose  Barbosa Nhoca     1731386
# 5        876913  1040582                       Georgios Lesaj     2056948
# 6        267068   269779      Mauricio Sebastián Gómez Castro     1396270
# 7        388825   399796    Mathías Fernando Rodríguez Laites     1608868
# 8        748875   886885                Brian Cordara Damasco     2202173
# 9        748875   886885                Brian Cordara Damasco     1545565
# 10       116160   100497  Alejandro Damián González Hernández     1106451
# 11       116160   100497  Alejandro Damián González Hernández      567948
# 12       596332   657755   Alexander Nicolás Machado Aycaguer     1219009
# 13       446701   452551        Cristian Daniel Cruz Regueiro     1544172
# 14        86600    76876       Maximiliano Lombardi Rodríguez      122975
# 15        86600    76876       Maximiliano Lombardi Rodríguez      169799
# 16        86600    76876       Maximiliano Lombardi Rodríguez      169798
# 17        86600    76876       Maximiliano Lombardi Rodríguez      122976
# 18        86600    76876       Maximiliano Lombardi Rodríguez      298213
# 19        86600    76876       Maximiliano Lombardi Rodríguez       17420
# 20        86600    76876       Maximiliano Lombardi Rodríguez      241316
# 21       140075   186498                         Milan  Savić     2226054
# 22       498672   479226                     Stefan Cvetković      882655
# 23       498672   479226                     Stefan Cvetković      674594
# 24       445320   374055                         Dragan Rosić      261242
# 25       680398   768106                    Andrija  Marković     1515068
# 26       140075   186498                         Milan  Savić      499695
# 27       721586   846123                 Mbouri Basile Yamkam     1452769
# 28       881940   858563                      Matija Petrović     2038643
# 29       140130   227550                         Stefan Dimić      249852
# 30       483015   423610                          Sava Petrov     2206384
# 31       483015   423610                          Sava Petrov      980025
# 32       483015   423610                          Sava Petrov      588491
# 33       127655    46695                      Saša Marjanović     1654830
# 34       619971   690551                       Danilo Djulcić      799390
# 35       366166   380097                          Ivan Djorić     1249802
# 36       366166   380097                          Ivan Djorić     1287646
# 37       366166   380097                          Ivan Djorić     1249803
# 38       366166   380097                          Ivan Djorić      955387
# 39        20807    70574                      Milan Milanović      136042
# 40        20807    70574                      Milan Milanović      136042
# 41        20807    70574                      Milan Milanović      783370
# 42       779285   708198                      Ilya  Guchmazov     1459101
# 43       779285   708198                      Ilya  Guchmazov     1459105
# 44       863947  1075664                      Giannis Vasilas     1772101
# 45       255420   266809                  Nicolás Omar Freire     2198353
# 46       213365   259930      Gabriel Matías Fernández Leites      243749
# 47       216649   238155                Arturo Ortíz Martínez      296715
# 48       216649   238155                Arturo Ortíz Martínez      759145
# 49       216649   238155                Arturo Ortíz Martínez     2354976
#
#     fromTeamId                    fromTeamName  toTeamId  \
# 0        12264  Club Atlético Sarmiento de Res     12066
# 1        23216                  Andes Talleres     12132
# 2        17383                      CD Motagua     23214
# 3        39691                      UD Montijo       731
# 4         <NA>                                        53
# 5        71504              AE Iraklis Larissa     12604
# 6         <NA>                            None     15637
# 7         <NA>                            None     15638
# 8        15638  Club Sportivo Miramar Misiones     15662
# 9          937                      Zamudio SD     15639
# 10       15642          Defensor Sporting Club     15532
# 11        3179                         Perugia      3194
# 12       15635             Club Atlético Cerro     15664
# 13       15631           Club Sportivo Cerrito     15630
# 14       17383                         Motagua     15599
# 15       15639                       Rentistas     15599
# 16       15599                    Los Caimanes     15644
# 17       15661                El Tanque Sisley     17383
# 18       15644              Central Español FC     15599
# 19       15635                           Cerro     12218
# 20       15653                        Progreso     15661
# 21        <NA>                            None     31417
# 22       17104                    FK Čukarički     17164
# 23       17090                   Crvena Zvezda     17201
# 24       17171           FK Kolubara Lazarevac     17105
# 25       65621             FK Radnički Niš U19     17117
# 26       17123                   FK Novi Pazar     15268
# 27        <NA>                            None     16747
# 28       17171           FK Kolubara Lazarevac     17111
# 29       17104                    FK Čukarički     17229
# 30       17111                 FK Radnički Niš      9683
# 31        5084                    KVC Westerlo     63141
# 32       36638                 FK Partizan U19     17220
# 33       17101            FK Napredak Kruševac     17111
# 34        <NA>                                     17123
# 35       31456  FK Crvena Zvezda Beograd Under     13145
# 36       17351            FK Iskra Danilovgrad     15274
# 37       13145                    FK Ventspils      6421
# 38       17101            FK Napredak Kruševac     17128
# 39        3188                          Ascoli      3171
# 40        3188                          Ascoli      3171
# 41       60145          Željezničar Banja Luka     11969
# 42       17164             FK Grafičar Beograd      <NA>
# 43        <NA>                            None     17164
# 44        <NA>                                     63226
# 45       66193  Club Internacional de Fútbol M     15420
# 46       15642               Defensor Sporting     15659
# 47       15424                       Club León     30286
# 48       15440          Correcaminos de la UAT     15441
# 49       63762           El Paso Locomotive FC     34402
#
#                         toTeamName active   startDate  ... transfer_value  \
# 0      Club Olimpo de Bahía Blanca      0  2023-01-05  ...              0
# 1          Independiente Rivadavia      0  2013-07-05  ...              0
# 2   Club Atlético San Lorenzo de A      1  2017-07-01  ...              0
# 3                   Rayo Cantabria      0  2024-01-24  ...              0
# 4                        Noordwijk      0  2022-07-01  ...              0
# 5                Diagoras Rodou FC      0  2023-08-05  ...              0
# 6   Montevideo Wanderers Fútbol Cl      0  2013-05-01  ...              0
# 7   Club Sportivo Miramar Misiones      0  2022-02-07  ...             NA
# 8                        La Luz FC      0  2024-01-26  ...              0
# 9          Club Atlético Rentistas      0  2020-01-01  ...              0
# 10       Club Sporting Cristal SAC      0  2021-01-03  ...             NA
# 11                   Hellas Verona      0  2018-06-30  ...             NA
# 12  Club Atlético Boston River S.A      0  2021-04-12  ...             NA
# 13             Danubio Fútbol Club      0  2022-01-03  ...              0
# 14                    Los Caimanes      0  2014-09-09  ...             NA
# 15                    Los Caimanes      0  2015-07-01  ...              0
# 16                 Central Español      0  2016-02-05  ...              0
# 17                         Motagua      0  2013-07-04  ...              0
# 18  Club Cultural y Deportivo Los       0  2016-08-28  ...             NA
# 19                     Boca Unidos      0  2010-06-29  ...             NA
# 20                El Tanque Sisley      0  2013-01-18  ...             NA
# 21                     FK Brodarac      0  2024-02-13  ...             NA
# 22             FK Grafičar Beograd      0  2020-01-14  ...             NA
# 23                   Bačka Palanka      0  2018-08-01  ...             NA
# 24               FK Mladost Lučani      0  2017-07-01  ...             NA
# 25        FK Radnicki Novi Beograd      0  2021-08-01  ...              0
# 31  2024-09-10 2024-09-07 14:32:10+00:00
# 32  2024-09-10 2024-09-07 14:32:10+00:00
# 33  2024-09-11 2024-09-07 14:32:10+00:00
# 34  2024-09-07 2024-09-07 14:27:45+00:00
# 35  2024-09-08 2024-09-07 14:31:16+00:00
# 36  2024-09-08 2024-09-07 14:31:16+00:00
# 37  2024-09-08 2024-09-07 14:31:16+00:00
# 38  2024-09-08 2024-09-07 14:31:16+00:00
# 39  2024-09-09 2024-09-07 14:31:16+00:00
# 40  2024-09-09 2024-09-07 14:31:16+00:00
# 41  2024-09-09 2024-09-07 14:31:16+00:00
# 42  2024-09-10 2024-09-07 14:31:16+00:00
# 43  2024-09-10 2024-09-07 14:31:16+00:00
# 44  2024-09-09 2024-09-07 14:27:45+00:00
# 45  2023-10-03 2023-09-30 17:51:20+00:00
# 46  2023-10-01 2023-09-30 22:31:31+00:00
# 47  2024-09-09 2024-09-07 14:27:45+00:00
# 48  2024-09-09 2024-09-07 14:27:45+00:00
# 49  2024-09-09 2024-09-07 14:27:45+00:00
#
#                                                  blob player_id  \
# 0   transfermarkt/player_transfers/ players_transf...    104871
# 1   transfermarkt/player_transfers/ players_transf...    104871
# 2   transfermarkt/player_transfers/ players_transf...    104871
# 3   transfermarkt/player_transfers/ players_transf...    976205
# 4   transfermarkt/player_transfers/ players_transf...    701527
# 5   transfermarkt/player_transfers/ players_transf...   1040582
# 6                                                None    269779
# 7   transfermarkt/player_transfers/ players_transf...    399796
# 8   transfermarkt/player_transfers/ players_transf...    886885
# 9   transfermarkt/player_transfers/ players_transf...    886885
# 10  transfermarkt/player_transfers/ players_transf...    100497
# 11  transfermarkt/player_transfers/ players_transf...    100497
# 12  transfermarkt/player_transfers/ players_transf...    657755
# 13  transfermarkt/player_transfers/ players_transf...    452551
# 14  transfermarkt/player_transfers/ players_transf...     76876
# 15  transfermarkt/player_transfers/ players_transf...     76876
# 16  transfermarkt/player_transfers/ players_transf...     76876
# 17  transfermarkt/player_transfers/ players_transf...     76876
# 18  transfermarkt/player_transfers/ players_transf...     76876
# 19  transfermarkt/player_transfers/ players_transf...     76876
# 20  transfermarkt/player_transfers/ players_transf...     76876
# 21                                               None    186498
# 22                                               None    479226
# 23                                               None    479226
# 24  transfermarkt/player_transfers/ players_transf...    374055
# 25  transfermarkt/player_transfers/ players_transf...    768106
# 26  transfermarkt/player_transfers/ players_transf...    186498
# 27  transfermarkt/player_transfers/ players_transf...    846123
# 28  transfermarkt/player_transfers/ players_transf...    858563
# 29  transfermarkt/player_transfers/ players_transf...    227550
# 30  transfermarkt/player_transfers/ players_transf...    423610
# 31  transfermarkt/player_transfers/ players_transf...    423610
# 32  transfermarkt/player_transfers/ players_transf...    423610
# 33  transfermarkt/player_transfers/ players_transf...     46695
# 34  transfermarkt/player_transfers/ players_transf...    690551
# 35  transfermarkt/player_transfers/ players_transf...    380097
# 36  transfermarkt/player_transfers/ players_transf...    380097
# 37  transfermarkt/player_transfers/ players_transf...    380097
# 38  transfermarkt/player_transfers/ players_transf...    380097
# 27   202109017567846123
# 28   202308017567858563
# 29   201606307567227550
# 30   201702187567423610
# 31   201702187567423610
# 32   201807017567423610
# 33    20190701756746695
# 34   202107017569690551
# 35   201601297569380097
# 36   201612317569380097
# 37   201612317569380097
# 38   201612317569380097
# 39    20150831756970574
# 40    20210912756970574
# 41    20210912756970574
# 42   201907017569708198
# 43   202108267569708198
# 44  2024080476321075664
# 45   202406307633266809
# 46   201808017633259930
# 47   201406307633238155
# 48   201406307633238155
# 49   201706307633238155
#
# [50 rows x 35 columns]

# %%
df4.head()
# Out:
#    wy_playerId    tm_id                 nombre  transferId  fromTeamId  \
# 0       240902   104871   Martín Ariel Pucheta     1895516       12264
# 1       240902   104871   Martín Ariel Pucheta        6559       23216
# 2       240902   104871   Martín Ariel Pucheta      514314       17383
# 5       876913  1040582         Georgios Lesaj     2056948       71504
# 9       748875   886885  Brian Cordara Damasco     1545565         937
#
#                      fromTeamName  toTeamId                      toTeamName  \
# 0  Club Atlético Sarmiento de Res     12066     Club Olimpo de Bahía Blanca
# 1                  Andes Talleres     12132         Independiente Rivadavia
# 2                      CD Motagua     23214  Club Atlético San Lorenzo de A
# 5              AE Iraklis Larissa     12604               Diagoras Rodou FC
# 9                      Zamudio SD     15639         Club Atlético Rentistas
#
#   active   startDate  ... transfer_value contract_expiry  \
# 0      0  2023-01-05  ...              0              NA
# 1      0  2013-07-05  ...              0              NA
# 2      1  2017-07-01  ...              0              NA
# 5      0  2023-08-05  ...              0              NA
# 9      0  2020-01-01  ...              0      2022-12-31
#
#                                           player_url  query_date  \
# 0  https://www.transfermarkt.com/martin-pucheta/p...  2024-09-10
# 1  https://www.transfermarkt.com/martin-pucheta/p...  2024-09-10
# 2  https://www.transfermarkt.com/martin-pucheta/p...  2024-09-10
# 5  https://www.transfermarkt.com/georgios-lleshaj...  2024-09-08
# 9  https://www.transfermarkt.com/brian-cordara/pr...  2024-09-09
#
#                   timestamp  \
# 0 2024-09-07 14:31:16+00:00
# 1 2024-09-07 14:31:16+00:00
# 2 2024-09-07 14:31:16+00:00
# 5 2024-09-07 14:27:45+00:00
# 9 2024-09-07 14:27:45+00:00
#
#                                                 blob player_id  \
# 0  transfermarkt/player_transfers/ players_transf...    104871
# 1  transfermarkt/player_transfers/ players_transf...    104871
# 2  transfermarkt/player_transfers/ players_transf...    104871
# 5  transfermarkt/player_transfers/ players_transf...   1040582
# 9  transfermarkt/player_transfers/ players_transf...    886885
#
#                                            teams_url team_id  \
# 0  https://www.transfermarkt.com/club-olimpo/star...    7468
# 1  https://www.transfermarkt.com/club-olimpo/star...    7468
# 2  https://www.transfermarkt.com/club-olimpo/star...    7468
# 5  https://www.transfermarkt.com/iraklis-larisas/...    7476
# 9  https://www.transfermarkt.com/miramar-misiones...    7477
#
#     player_transfer_id
# 0   202107017468104871
# 1   202107017468104871
# 2   202107017468104871
# 5  2021070174761040582
# 9   202206237477886885
#
# [5 rows x 35 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2940696 entries, 0 to 4560962
# Data columns (total 35 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   wy_playerId         Int64
#  1   tm_id               Int64
#  2   nombre              object
#  3   transferId          Int64
#  4   fromTeamId          Int64
#  5   fromTeamName        object
#  6   toTeamId            Int64
#  7   toTeamName          object
#  8   active              object
#  9   startDate           dbdate
#  10  endDate             dbdate
#  11  type                object
#  12  value               object
#  13  currency            object
#  14  announceDate        object
#  15  playerId            Int64
#  16  tm_playerId         object
#  17  wy_id               Int64
#  18  row_ind             object
#  19  player_name         object
#  20  season              object
#  21  transfer_date       object
#  22  team_from           object
#  23  team_to             object
#  24  market_value        object
#  25  transfer_value      object
#  26  contract_expiry     object
#  27  player_url          object
#  28  query_date          dbdate
#  29  timestamp           datetime64[us, UTC]
#  30  blob                object
#  31  player_id           object
#  32  teams_url           object
#  33  team_id             object
#  34  player_transfer_id  object
# dtypes: Int64(7), datetime64[us, UTC](1), dbdate(3), object(24)
# memory usage: 827.3+ MB

# %%
df4.tail()
# Out:
#          wy_playerId   tm_id                     nombre  transferId  \
# 4560958       215333  245315                Eric Miller       59943
# 4560959       216964  231923               Aljaž Ivačič      502103
# 4560960        90838  165361  Yimmi Javier Chará Zamora      296470
# 4560961        90838  165361  Yimmi Javier Chará Zamora      489236
# 4560962       351808  344015               Ben Woodburn     1422599
#
#          fromTeamId             fromTeamName  toTeamId  \
# 4560958        8142          Montreal Impact      7853
# 4560959       12004              NK Radomlje     11953
# 4560960       15465  CSyD Dorados de Sinaloa     15444
# 4560961       15444             CF Monterrey     12391
# 4560962        1612             Liverpool FC      8510
#
#                         toTeamName active   startDate  ... transfer_value  \
# 4560958            Colorado Rapids      1  2016-02-14  ...             NA
# 4560959                   Olimpija      1  2017-08-31  ...             NA
# 4560960               CF Monterrey      0  2016-06-30  ...             NA
# 4560961  Club Atlético Nacional SA      0  2015-07-01  ...             NA
# 4560962     Heart of Midlothian FC      0  2021-08-23  ...             NA
#
#         contract_expiry                                         player_url  \
# 4560958              NA  https://www.transfermarkt.com/eric-miller/prof...
# 4560959      2025-12-31  https://www.transfermarkt.com/aljaz-ivacic/pro...
# 4560960      2015-12-31  https://www.transfermarkt.com/yimmi-chara/prof...
# 4560961      2015-12-31  https://www.transfermarkt.com/yimmi-chara/prof...
# 4560962      2022-06-30  https://www.transfermarkt.com/ben-woodburn/pro...
#
#          query_date                 timestamp  \
# 4560958  2024-09-10 2024-09-07 14:27:45+00:00
# 4560959  2024-09-10 2024-09-07 14:27:45+00:00
# 4560960  2024-09-11 2024-09-07 14:32:10+00:00
# 4560961  2024-09-11 2024-09-07 14:32:10+00:00
# 4560962  2024-09-08 2024-09-07 14:27:45+00:00
#
#                                                       blob player_id  \
# 4560958  transfermarkt/player_transfers/ players_transf...    245315
# 4560959  transfermarkt/player_transfers/ players_transf...    231923
# 4560960  transfermarkt/player_transfers/ players_transf...    165361
# 4560961  transfermarkt/player_transfers/ players_transf...    165361
# 4560962  transfermarkt/player_transfers/ players_transf...    344015
#
#                                                  teams_url team_id  \
# 4560958  https://www.transfermarkt.com/portland-timbers...    4291
# 4560959  https://www.transfermarkt.com/portland-timbers...    4291
# 4560960  https://www.transfermarkt.com/portland-timbers...    4291
# 4560961  https://www.transfermarkt.com/portland-timbers...    4291
# 4560962  https://www.transfermarkt.com/preston-north-en...     466
#
#          player_transfer_id
# 4560958  201911264291245315
# 4560959  202403194291231923
# 4560960  201512314291165361
# 4560961  201512314291165361
# 4560962   20180801466344015
#
# [5 rows x 35 columns]

# %%
# Obtener el rango de fechas en df4
fecha_inicio_df4 = df4['startDate'].min()
fecha_fin_df4 = df4['endDate'].max()

print(f"El rango de fechas en df4 es de {fecha_inicio_df4} a {fecha_fin_df4}")
# Out:
# El rango de fechas en df4 es de 1996-07-01 a 2030-06-30

# %%
# Realizar un merge de df3 y df4 con indicador para identificar las filas que no coinciden
merged_df = df3.merge(df4, on=['wy_ adplayerId', 'tm_id'], how='left', indicator=True)

# Filtrar las filas que están solo en df3
not_in_df4 = merged_df[merged_df['_merge'] == 'left_only']

# Eliminar la columna '_merge' ya que no es necesaria
not_in_df4 = not_in_df4.drop(columns=['_merge'])

# Mostrar los resultados
print(not_in_df4)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Realizar un merge de df3 y df4 con indicador para identificar las filas que no coinciden
# ----> 2 merged_df = df3.merge(df4, on=['wy_playerId', 'tm_id'], how='left', indicator=True)
#       4 # Filtrar las filas que están solo en df3
#       5 not_in_df4 = merged_df[merged_df['_merge'] == 'left_only']
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
#   10837         left_on=left_on,
#   10838         right_on=right_on,
#   10839         left_index=left_index,
#   10840         right_index=right_index,
#   10841         sort=sort,
#   10842         suffixes=suffixes,
#   10843         copy=copy,
#   10844         indicator=indicator,
#   10845         validate=validate,
#   10846     )
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:848, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     840 llabels, rlabels = _items_overlap_with_suffix(
#     841     self.left._info_axis, self.right._info_axis, self.suffixes
#     842 )
#     844 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     845     # Pinning the index here (and in the right code just below) is not
#     846     #  necessary, but makes the `.take` more performant if we have e.g.
#     847     #  a MultiIndex for left.index.
# --> 848     lmgr = left._mgr.reindex_indexer(
#     849         join_index,
#     850         left_indexer,
#     851         axis=1,
#     852         copy=False,
#     853         only_slice=True,
#     854         allow_dups=True,
#     855         use_na_proxy=True,
#     856     )
#     857     left = left._constructor_from_mgr(lmgr, axes=lmgr.axes)
#     858 left.index = join_index
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:688, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 107. GiB for an array with shape (24, 596066062) and data type object

# %%
dftext2 = df2.to_csv(index=False)

# %%
prompt1= """Que informacion vez en estos textos?"""

# %%
##salida armoa
def generate():
  vertexai.init(project=PROJECT_ID, location=LOCATION)
  responses = model.generate_content(
      [dftext, dftext2, prompt1],
      generation_config=generation_config,
      safety_settings=safety_settings,
      stream=True,
  )

  for response in responses:
    print(response.text, end="")


generate()
# Out:
# These texts contain data about football (soccer) clubs across various leagues and countries.  The information includes:
#
# * **Geographic Location:** Region (e.g., Europe, South America), Country (e.g., Spain, Brazil), and sometimes more specific area names.
#
# * **League and Club Information:** The name of the league (e.g., La Liga, MLS) and the specific football club (e.g., Real Madrid, Atlanta United).  There's also a division level specified for each domestic competition.
#
# * **Attendance Data:** Weekly average attendance and annual average attendance figures.
#
# * **Currency:** The currency in which the attendance figures are reported (e.g., euros, dollars).
#
# * **Unique Identifiers:**  `wyId` for some entries, providing a unique identifier for each club.  There's also a `name` and `officialName` for each club.
#
#
# In short, the data represents a dataset suitable for analysis of football club attendance across different leagues and regions.  The inclusion of `wyId` suggests the data might be from a larger database or API.

# %%
prompt2= """Sos un agente que analiza datos tu funcion es generar una unica tabla a partir de la informacion que te doy en 2 csv, que corresponden a 2 tablas.
Estos textos contienen informacion de dos tablas:
El primer texto contiene la informacion de la primera tabla que contiene las siguientes columnas: 	
-region: corresponde a la region de donde es el club
-pais: corresponde al pais de donde es el club	
-liga: corresponde a la liga del club	
-club: corresponde al nombre del club	
-weeklyavg:	corresponde al salario semanal promedio por jugador del club
-annualavg: corresponde al salario anual promedio por jugador del club	
-moneda: corresponde a la moneda en la que se mide el salario
Y tiene 570 filas
El segundo texto contiene la informacion de la segunda tabla que contiene las siguientes columnas:
-wyId: corresponde al id del club	
-name: corresponde al nombre del club	
-officialName: corresponde al nombre oficial del club, puede ser levemente diferente al nombre o contenter alguna palabra mas.	
-area_name: corresponde al pais de donde es el club
-domestic_competition_name: corresponde a la liga del club		
-region: corresponde a la region de donde es el club
y contiene 2000 filas
La infomacion en ambas tablas es muy similar. La tabla 2 deberia tener todos los clubes de la tabla 1, no asi al revez. La tablta 1 tiene muchas menos filas que la tabla dos. 
El objetivo es encontrar el id de los clubes de la tabla 1, en la tabla 2 y crear una tabla final que contenga la informacion de la tabla 1 pero con wl wyId de la tabla dos.
La tabla final tiene que contenter la union de estas dos tablas con la informacion de ambas tablas, pero solo con los clubes que estan en ambas tablas.
Es decir solamente tienen que quedar en el resultado, los valores que coinciden dentro de las dos tablas con su ID, deberian ser la misma cantidad de valores que la primera tabla
Quiero que vos hagas la tabla. No quiero que me des el codigo de SQL para hacerlo yo.
Quiero que lo hagas con todos los valores de la tabla uno hasta terminar de leer ambos textos.
Es decir necesito que me devuelvas los 570 clubes del dftext con su wyid en una tabla.
La respuesta tiene que ser unicamente esta tabla de 570 filas con las columnas  region | pais | liga | club | weeklyavg | annualavg | moneda | domestic_competition_divisionLevel | wyId | name | officialName | area_name | domestic_competition_name 
"""

# %%
def generate():
  vertexai.init(project=PROJECT_ID, location=LOCATION)
  model3 = GenerativeModel("gemini-1.5-pro-preview-0409")
  responses = model3.generate_content(
      [dftext, dftext2, prompt2],
      generation_config=generation_config,
      safety_settings=safety_settings,
      stream=True,
  )
    # Captura el texto completo en una variable
  full_text = ""
  for response in responses:
      full_text += response.text

  return full_text

# Ejecuta la función y captura el texto generado
result_text = generate()

print(result_text)
# Out:
# ```
# region | pais | liga | club | weeklyavg | annualavg | moneda | domestic_competition_divisionLevel | wyId | name | officialName | area_name | domestic_competition_name
# ------- | -------- | -------- | -------- | -------- | -------- | -------- | -------- | -------- | -------- | -------- | --------
# Europe | Spain | La Liga 2 | Levante | 4895 | 254545 | euros | 2 | 695 | Levante | Levante UD | Spain | Segunda División
# Europe | Spain | La Liga 2 | Real Oviedo | 5789 | 301029 | euros | 2 | 789 | Real Oviedo | Real Oviedo | Spain | Segunda División
# Europe | Spain | La Liga 2 | Eibar | 7262 | 377647 | euros | 2 | 701 | Eibar | SD Eibar | Spain | Segunda División
# Europe | Spain | La Liga 2 | Sporting Gijon | 5235 | 272222 | euros | 2 | 697 | Sporting Gijón | Real Sporting de Gijón | Spain | Segunda División
# Europe | Spain | La Liga 2 | Elche | 8251 | 429048 | euros | 2 | 702 | Elche | Elche CF | Spain | Segunda División
# Europe | Spain | La Liga 2 | Albacete | 3603 | 187368 | euros | 2 | 685 | Albacete | Albacete Balompié | Spain | Segunda División
# Europe | Spain | La Liga 2 | Eldense | 2354 | 122400 | euros | 2 | 845 | Eldense | CD Eldense | Spain | Segunda División
# Europe | Spain | La Liga 2 | Huesca | 3822 | 198750 | euros | 2 | 802 | Huesca | SD Huesca | Spain | Segunda División
# Europe | Spain | La Liga 2 | Almeria | 9808 | 510000 | euros | 2 | 708 | Almería | UD Almería | Spain | Segunda División
# Europe | Spain | La Liga 2 | Zaragoza | 4292 | 223200 | euros | 2 | 689 | Real Zaragoza | Real Zaragoza | Spain | Segunda División
# South America | Colombia | Primera A | Santa Fe | 4867 | 253077 | dolares | 1 | 12404 | Santa Fe | Club Independiente Santa Fe | Colombia | Liga BetPlay
# South America | Colombia | Primera A | Patriotas | 2543 | 132258 | dolares | 1 | 12421 | Patriotas Boyacá | Corporación Deportiva Patriotas FC | Colombia | Liga BetPlay
# South America | Colombia | Primera A | Pereira | 4088 | 212581 | dolares | 1 | 12395 | Deportivo Pereira | Corporación Social Deportiva y Cultural de Pereira | Colombia | Liga BetPlay
# South America | Colombia | Primera A | Junior FC | 5341 | 277742 | dolares | 1 | 12393 | Junior | Club Deportivo Junior FC S.A. | Colombia | Liga BetPlay
# South America | Colombia | Primera A | Once Caldas | 3762 | 195625 | dolares | 1 | 12392 | Once Caldas | Once Caldas SA | Colombia | Liga BetPlay
# South America | Colombia | Primera A | Deportivo Boyacá Chicó FC S.A. | 2140 | 111290 | dolares | 1 | 12398 | Boyacá Chicó | Deportivo Boyacá Chicó FC S.A. | Colombia | Liga BetPlay
# South America | Colombia | Primera A | Millonarios | 5798 | 301471 | dolares | 1 | 12400 | Millonarios | Millonarios FC SA | Colombia | Liga BetPlay
# South America | Colombia | Primera A | Águilas Doradas | 3036 | 157857 | dolares | 1 | 12413 | Águilas Doradas | Águilas Doradas S.A. | Colombia | Liga BetPlay
# South America | Colombia | Primera A | La Equidad | 3469 | 180400 | dolares | 1 | 12411 | La Equidad | Club Deportivo La Equidad Seguros | Colombia | Liga BetPlay

# %% [markdown]
# bucle pero da medio desordenado

# %%
def generate():
    vertexai.init(project=PROJECT_ID, location=LOCATION)
    model3 = GenerativeModel("gemini-1.5-pro-preview-0409")
    
    # Inicializamos un conjunto para almacenar filas únicas
    unique_rows = set()
    
    while len(unique_rows) < 570:
        # Realizamos la llamada al modelo
        responses = model3.generate_content(
            [dftext, dftext2, prompt2],
            generation_config=generation_config,
            safety_settings=safety_settings,
            stream=True,
        )
        
        for response in responses:
            # Dividimos la respuesta generada en filas
            rows = response.text.strip().split('\n')
            
            # Añadimos las filas al conjunto para eliminar duplicados
            unique_rows.update(rows)

        # Verificamos si ya tenemos 570 filas únicas
        if len(unique_rows) >= 570:
            break
    
    # Unimos las filas únicas en un solo texto
    full_text = "\n".join(unique_rows)

    return full_text

# %% [markdown]
# pruebo con el mismo prompt pero con un bucle
# ES EL QUE FUNCIONA!!!! VA ITERANDO DE A 100 FILAS, LA VARIABLE QUE ITERO ESTA EN DATAFRAME, LA QUE LE PASO PARA COMPARAR ESTA EN CSV

# %%
import pandas as pd

def generate():
    vertexai.init(project=PROJECT_ID, location=LOCATION)
    model3 = GenerativeModel("gemini-1.5-pro-preview-0409")
    
    # Lee el archivo CSV como un DataFrame
    df1 #df1 = pd.read_csv('ruta/al/archivo/df1.csv')  # Reemplaza con la ruta correcta
    df2 #dftext2 = pd.read_csv('ruta/al/archivo/dftext2.csv')  # Reemplaza con la ruta correcta

    # Inicializamos variables para acumular el texto
    full_text = ""
    total_rows = df1.shape[0]
    batch_size = 100  # Tamaño del lote

    # Itera sobre el DataFrame en lotes
    for i in range((total_rows + batch_size - 1) // batch_size):  # Asegura que se cubran todos los lotes
        batch = df1[i * batch_size:(i + 1) * batch_size]

        # Convierte el lote a un formato de texto (CSV sin encabezados)
        batch_text = batch.to_csv(index=False, header=False)

        # Realiza la llamada al modelo con el lote actual
        responses = model3.generate_content(
            [batch_text, dftext2, prompt2],  # Asegúrate de que df12 esté en el formato correcto
            generation_config=generation_config,
            safety_settings=safety_settings,
            stream=True,
        )
        
        # Captura las respuestas generadas
        for response in responses:
            full_text += response.text

    return full_text

# Llama a la función para generar el texto
result_text = generate()

# %%
print(result_text)
# Out:
# ```
# | region | pais | liga | club | weeklyavg | annualavg | moneda | domestic_competition_divisionLevel | wyId | name | officialName | area_name | domestic_competition_name |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# | Central/North America | United States | MLS | Atlanta United | 6451 | 335452 | dolares | 1 | 58165 | Atlanta United | Atlanta United FC | United States | MLS |
# | Central/North America | United States | MLS | New England Revolution | 9209 | 478875 | dolares | 1 | 7854 | New England | New England Revolution | United States | MLS |
# | Central/North America | United States | MLS | Philadelphia Union | 6990 | 363486 | dolares | 1 | 8061 | Philadelphia Union | Philadelphia Union | United States | MLS |
# | Central/North America | United States | MLS | Seattle Sounders | 10668 | 554728 | dolares | 1 | 8067 | Seattle Sounders | Seattle Sounders FC | United States | MLS |
# | Central/North America | United States | MLS | Nashville SC | 11651 | 605862 | dolares | 1 | 30149 | Nashville SC | Nashville SC | United States | MLS |
# | Central/North America | United States | MLS | Minnesota United | 6842 | 355810 | dolares | 1 | 8095 | Minnesota United | Minnesota United FC | United States | MLS |
# | Central/North America | United States | MLS | Orlando City | 8178 | 425248 | dolares | 1 | 8068 | Orlando City | Orlando City SC | United States | MLS |
# | Central/North America | Canada | MLS | Toronto FC | 13244 | 688666 | dolares | 1 | 14995 | Toronto | Toronto FC | Canada | MLS |
# | Central/North America | United States | MLS | FC Cincinnati | 9171 | 476900 | dolares | 1 | 37892 | Cincinnati | FC Cincinnati | United States | MLS |
# | Central/North America | United States | MLS | Colorado Rapids | 8771 | 456102 | dolares | 1 | 7853 | Colorado Rapids | Colorado Rapids | United States | MLS |
# Europe | Denmark | Superligaen | København | 12885 | 670000 | euros | 1 | 7452 | København | FC København | Denmark | Superliga
# Europe | Denmark | Superligaen | Midtjylland | 6274 | 326250 | euros | 1 | 7455 | Midtjylland | FC Midtjylland | Denmark | Superliga
# Europe | Denmark | Superligaen | Midtjylland | 6274 | 326250 | euros | 1 | 7455 | Midtjylland | FC Midtjylland | Denmark | Superliga
# Europe | Denmark | Superligaen | Sonderjyske | 62 | 3214 | euros | 1 | 7499 | SønderjyskE | SønderjyskE | Denmark | Superliga
# Europe | Denmark | Superligaen | Sonderjyske | 62 | 3214 | euros | 1 | 7499 | SønderjyskE | SønderjyskE | Denmark | Superliga
# Europe | Denmark | Superligaen | Nordsjaelland | 3830 | 199167 | euros | 1 | 7458 | Nordsjælland | FC Nordsjælland | Denmark | Superliga
# Europe | Denmark | Superligaen | Nordsjaelland | 3830 | 199167 | euros | 1 | 7458 | Nordsjælland | FC Nordsjælland | Denmark | Superliga
# ```

# %%
matches = re.findall(r'\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|', result_text)

# Convierte los datos en un DataFrame de pandas y asigna las columnas correctamente
dfunion = pd.DataFrame(matches)#, columns=[club | liga | pais | wyId | officialName | name | area_name | domestic_competition_name ])

dfunion = dfunion[~dfunion.eq('---').all(axis=1)]
dfunion.columns = dfunion.iloc[0]  # La primera fila se convierte en nombres de columna
dfunion = dfunion[1:]
# Resetea el índice
dfunion.reset_index(drop=True, inplace=True)

print(dfunion)

# %%
dfunion.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dfunion.head()
#
# NameError: name 'dfunion' is not defined

# %%
dfunion.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dfunion.info()
#
# NameError: name 'dfunion' is not defined

# %%
# Especifica tu ID de proyecto
project_id = 'ldp-data-wyscout'

# Crear un cliente de BigQuery con el proyecto especificado
client = bigquery.Client(project=project_id)

# Especificar la tabla de destino en el formato dataset.tabla
table_id = 'ldp-data-wyscout.otras_fuentes.capology_gemini'

# Configurar la carga de datos
job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,  # Reemplaza la tabla si ya existe
)

# Guardar el DataFrame en BigQuery
job = client.load_table_from_dataframe(dfunion, table_id, job_config=job_config)
job.result()  # Esperar a que el trabajo termine

print(f"Los datos han sido cargados en la tabla {table_id}.")
# Out:
# Los datos han sido cargados en la tabla ldp-data-wyscout.otras_fuentes.capology_gemini.

# %%
prompt=f"""Sos un agente que analiza datos tu funcion es generar una unica tabla a partir de la informacion que te doy en 2 csv, que corresponden a 2 tablas.
Estos textos contienen informacion de dos tablas:
El primer texto:{dftext} contiene la informacion de la primera tabla que contiene las siguientes columnas: 	
-region: corresponde a la region de donde es el club
-pais: corresponde al pais de donde es el club	
-liga: corresponde a la liga del club	
-club: corresponde al nombre del club	
-weeklyavg:	corresponde al salario semanal promedio por jugador del club
-annualavg: corresponde al salario anual promedio por jugador del club	
-moneda: corresponde a la moneda en la que se mide el salario
El segundo texto: {dftext2} contiene la informacion de la segunda tabla que contiene las siguientes columnas:
-wyId: corresponde al id del club	
-name: corresponde al nombre del club	
-officialName: corresponde al nombre oficial del club, puede ser levemente diferente al nombre o contenter alguna palabra mas.	
-area_name: corresponde al pais de donde es el club
-domestic_competition_name: corresponde a la liga del club		
-region: corresponde a la region de donde es el club
La infomacion en ambas tablas es muy similar. La tabla 2 deberia tener todos los clubes de la tabla 1, no asi al revez. La tablta 1 tiene muchas menos filas que la tabla dos. 
El objetivo es encontrar el id de los clubes de la tabla 1, en la tabla 2. 
La tabla final tiene que contenter la union de estas dos tablas con la informacion de ambas tablas, pero solo con los clubes que estan en ambas tablas.
Es decir solamente tienen que quedar en el resultado, los valores que coinciden dentro de las dos tablas con su ID, deberian ser la misma cantidad de valores que la primera tabla
Quiero que vos hagas la tabla. No quiero que me des el codigo de SQL para hacerlo yo."""

responses = model.generate_content(prompt, generation_config=generation_config, stream=True)

# Inicializar una variable para almacenar el resultado completo
full_response = ""

# Recopilar y unir todas las partes de la respuesta
for response in responses:
    full_response += response.text

# Imprimir o usar la respuesta completa almacenada en la variable
print(full_response)

# %%
pattern = r'\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|'
matches = re.findall(pattern, full_response)

# Convierte los datos en un DataFrame de pandas y asigna las columnas correctamente
dfunion = pd.DataFrame(matches)#, columns=[club | liga | pais | wyId | officialName | name | area_name | domestic_competition_name ])

dfunion = dfunion[~dfunion.eq('---').all(axis=1)]
dfunion.columns = dfunion.iloc[0]  # La primera fila se convierte en nombres de columna
dfunion = dfunion[1:]
# Resetea el índice
dfunion.reset_index(drop=True, inplace=True)

print(dfunion)

# %%
prompt22=f"""Sos un agente que analiza datos tu funcion es generar una unica tabla a partir de la informacion que te doy en 2 csv, que corresponden a 2 tablas.
Estos textos contienen informacion de dos tablas:
El primer texto:{dftext} contiene la informacion de la primera tabla que contiene las siguientes columnas: 	
-region: corresponde a la region de donde es el club
-pais: corresponde al pais de donde es el club	
-liga: corresponde a la liga del club	
-club: corresponde al nombre del club	
-weeklyavg:	corresponde al salario semanal promedio por jugador del club
-annualavg: corresponde al salario anual promedio por jugador del club	
-moneda: corresponde a la moneda en la que se mide el salario
El segundo texto: {dftext2} contiene la informacion de la segunda tabla que contiene las siguientes columnas:
-wyId: corresponde al id del club	
-name: corresponde al nombre del club	
-officialName: corresponde al nombre oficial del club, puede ser levemente diferente al nombre o contenter alguna palabra mas.	
-area_name: corresponde al pais de donde es el club
-domestic_competition_name: corresponde a la liga del club		
-region: corresponde a la region de donde es el club
La infomacion en ambas tablas es muy similar. La tabla 2 deberia tener todos los clubes de la tabla 1, no asi al revez. La tablta 1 tiene muchas menos filas que la tabla dos. 
El objetivo es encontrar el id de los clubes de la tabla 1, en la tabla 2. 
La tabla final tiene que contenter la union de estas dos tablas con la informacion de ambas tablas, pero solo con los clubes que estan en la primera tabla. Tiene que haber aproximadamente 570 clubes.
Es decir solamente tienen que quedar en el resultado, los valores que coinciden dentro de las dos tablas con su ID, deberian ser la misma cantidad de valores que la primera tabla
Quiero que vos hagas la tabla. No quiero que me des el codigo de SQL para hacerlo yo.
Si hay valores similares unificalos, por ejemplo region de ambas tablas, pais de una con area_name de otra, club con name y officialName, liga con domestic_competition_name"""

responses2 = model.generate_content(prompt22, generation_config=generation_config, stream=True)

# Inicializar una variable para almacenar el resultado completo
full_response2 = ""

# Recopilar y unir todas las partes de la respuesta
for response in responses2:
    full_response2 += response.text

# Imprimir o usar la respuesta completa almacenada en la variable
print(full_response2)
# Out:
# ## Tabla Combinada de Clubes de Fútbol
#
# | wyId | region | pais | liga | club | weeklyavg | annualavg | moneda | officialName | area_name | domestic_competition_name |
# |---|---|---|---|---|---|---|---|---|---|---|
# | 12397 | South America | Colombia | Liga BetPlay | Pasto | 3314 | 172308 | dolares | Asociación Deportivo Pasto | Colombia | Liga BetPlay |
# | 12405 | South America | Colombia | Liga BetPlay | Envigado | 3183 | 165517 | dolares | Envigado FC | Colombia | Liga BetPlay |
# | 12392 | South America | Colombia | Liga BetPlay | Once Caldas | 3762 | 195625 | dolares | Once Caldas SA | Colombia | Liga BetPlay |
# | 12425 | South America | Colombia | Liga BetPlay | Alianza | 3293 | 171250 | dolares | Alianza FC | Colombia | Liga BetPlay |
# | 12421 | South America | Colombia | Liga BetPlay | Patriotas Boyacá | 2543 | 132258 | dolares | Corporación Deportiva Patriotas FC | Colombia | Liga BetPlay |
# | 12413 | South America | Colombia | Liga BetPlay | Águilas Doradas | 3036 | 157857 | dolares | Águilas Doradas S.A. | Colombia | Liga BetPlay |
# | 12427 | South America | Colombia | Liga BetPlay | Fortaleza | 3146 | 163600 | dolares | Fortaleza CEIF FC | Colombia | Liga BetPlay |
# | 12393 | South America | Colombia | Liga BetPlay | Junior | 5341 | 277742 | dolares | Club Deportivo Junior FC S.A. | Colombia | Liga BetPlay |
# | 12401 | South America | Colombia | Liga BetPlay | Atlético Bucaramanga | 4003 | 208148 | dolares | Club Atlético Bucaramanga CD | Colombia | Liga BetPlay |
# | 12394 | South America | Colombia | Liga BetPlay | Deportivo Cali | 4800 | 249600 | dolares | Asociación Deportivo Cali | Colombia | Liga BetPlay |
# | 12400 | South America | Colombia | Liga BetPlay | Millonarios | 5798 | 301471 | dolares | Millonarios FC SA | Colombia | Liga BetPlay |
# | 12398 | South America | Colombia | Liga BetPlay | Boyacá Chicó | 2140 | 111290 | dolares | Deportivo Boyacá Chicó FC S.A. | Colombia | Liga BetPlay |
# | 12396 | South America | Colombia | Liga BetPlay | Tolima | 4279 | 222500 | dolares | Club Deportes Tolima S.A. | Colombia | Liga BetPlay |
# | 12403 | South America | Colombia | Torneo BetPlay | Atlético Huila | 0 | 0 | dolares | Club Deportivo Atlético Huila | Colombia | Torneo BetPlay |
# | 12399 | South America | Colombia | Liga BetPlay | Medellín | 4237 | 220333 | dolares | Deportivo Independiente Medellín S.A. | Colombia | Liga BetPlay |
# | 24749 | South America | Colombia | Liga BetPlay | Jaguares de Córdoba | 0 | 0 | dolares | CD Jaguares de Córdoba | Colombia | Liga BetPlay |
# | 12411 | South America | Colombia | Liga BetPlay | La Equidad | 3469 | 180400 | dolares | Club Deportivo La Equidad Seguros | Colombia | Liga BetPlay |
# | 12390 | South America | Colombia | Liga BetPlay | América de Cali | 6083 | 316296 | dolares | Sociedad Anónima Deportiva América S.A. | Colombia | Liga BetPlay |
|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|'
matches2 = re.findall(pattern2, full_response2)

# Convierte los datos en un DataFrame de pandas y asigna las columnas correctamente
dfunion2 = pd.DataFrame(matches2)#, columns=[club | liga | pais | wyId | officialName | name | area_name | domestic_competition_name ])

dfunion2 = dfunion2[~dfunion2.eq('---').all(axis=1)]
dfunion2.columns = dfunion2.iloc[0]  # La primera fila se convierte en nombres de columna
dfunion2 = dfunion2[1:]
# Resetea el índice
dfunion2.reset_index(drop=True, inplace=True)

dfunion2.head()
# Out:
# 0   wyId         region      pais          liga              club weeklyavg  \
# 0  12397  South America  Colombia  Liga BetPlay             Pasto      3314
# 1  12405  South America  Colombia  Liga BetPlay          Envigado      3183
# 2  12392  South America  Colombia  Liga BetPlay       Once Caldas      3762
# 3  12425  South America  Colombia  Liga BetPlay           Alianza      3293
# 4  12421  South America  Colombia  Liga BetPlay  Patriotas Boyacá      2543
#
# 0 annualavg   moneda                        officialName area_name  \
# 0    172308  dolares          Asociación Deportivo Pasto  Colombia
# 1    165517  dolares                         Envigado FC  Colombia
# 2    195625  dolares                      Once Caldas SA  Colombia
# 3    171250  dolares                          Alianza FC  Colombia
# 4    132258  dolares  Corporación Deportiva Patriotas FC  Colombia
#
# 0 domestic_competition_name
# 0              Liga BetPlay
# 1              Liga BetPlay
# 2              Liga BetPlay
# 3              Liga BetPlay
# 4              Liga BetPlay

# %%
dfunion2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   wyId                       185 non-null    object
#  1   region                     185 non-null    object
#  2   pais                       185 non-null    object
#  3   liga                       185 non-null    object
#  4   club                       185 non-null    object
#  5   weeklyavg                  185 non-null    object
#  6   annualavg                  185 non-null    object
#  7   moneda                     185 non-null    object
#  8   officialName               185 non-null    object
#  9   area_name                  185 non-null    object
#  10  domestic_competition_name  185 non-null    object
# dtypes: object(11)
# memory usage: 16.0+ KB

# %% [markdown]
# ya no me da mas bien lo q me daba bien antes

# %%
prompt5 = f"""Sos un agente que analiza datos necesito que generes una tabla con la union de la informacion de dos tablas, a partir del analisis de 2 tablas.
La primera tabla contiene las columnas region, club, liga, pais de 570 clubes y la segunda tabla contiene las columnas  wyId, officialName,name, area_name y comestic_competition_name con 28425 valores. Lo que yo necesito que hagas es, encontrar las coincidencias
entre todos los valores de las columnas y a partir de esas coincidencias obtener el valor del id en el campo "wyId" de la segunda tabla
estas son las tablas: {dftext} y {dftext2}
Es decir solamente tienen que quedar en el resultado, los valores que coinciden dentro de las dos tablas con su ID, deberian ser la misma cantidad de valores que la tabla inicial
   """
# Generar la respuesta utilizando el prompt actualizado
responses5 = model.generate_content(prompt5, generation_config=generation_config, stream=True)

# Inicializar una variable para almacenar el resultado completo
full_response5 = ""

# Recopilar y unir todas las partes de la respuesta
for response5 in responses5:
    full_response5 += response5.text

# Imprimir o usar la respuesta completa almacenada en la variable
print(full_response5)
# Out:
# Entiendo perfectamente lo que necesitas. Para unir la información de ambas tablas y obtener el "wyId" correspondiente a cada club, necesitas realizar una unión basada en las coincidencias entre los valores de las columnas.
#
# Sin embargo, para poder generar la tabla de unión, necesito que me proporciones la segunda tabla con los datos de "wyId, officialName, name, area_name y comestic_competition_name".
#
# Una vez que me proporciones la segunda tabla, puedo realizar la unión y generar la tabla resultante con las columnas:
#
# * **region**
# * **pais**
# * **liga**
# * **club**
# * **weeklyavg**
# * **annualavg**
# * **moneda**
# * **wyId**
#
# **Ejemplo de cómo se vería la tabla resultante:**
#
# | region | pais | liga | club | weeklyavg | annualavg | moneda | wyId |
# |---|---|---|---|---|---|---|---|
# | Asia | Arabia Saudita | Saudi Pro League | Al Ahli | 106842 | 5555806 | euros | 16465 |
# | Asia | Arabia Saudita | Saudi Pro League | Al Ettifaq | 40740 | 2118462 | euros | 16468 |
# | Asia | Arabia Saudita | Saudi Pro League | Al Hilal | 212861 | 11068750 | euros | 16467 |
# | Asia | Arabia Saudita | Saudi Pro League | Al Ittihad | 111684 | 5807576 | euros | 16469 |
# | Asia | Arabia Saudita | Saudi Pro League | Al Nassr | 213994 | 11127667 | euros | 16470 |
# | Asia | Arabia Saudita | Saudi Pro League | Al Shabab | 18109 | 941667 | euros | 16472 |
# | Europa | Italia | Serie A | AC Milan | 67415 | 3505556 | euros | 3168 |
# | Europa | Italia | Serie A | Atalanta | 40057 | 2082963 | euros | 3172 |
# | Europa | Italia | Serie A | Bologna | 18112 | 941818 | euros | 3166 |
# | ... | ... | ... | ... | ... | ... | ... | ... |
#
# **Recuerda que la tabla resultante solo incluirá los clubes que coincidan en ambas tablas.**
#
# Por favor, proporciona la segunda tabla para que pueda generar la tabla de unión.

# %%
matches = re.findall(r'\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|', full_response)

# Convierte los datos en un DataFrame de pandas y asigna las columnas correctamente
df3 = pd.DataFrame(matches)#, columns=[club | liga | pais | wyId | officialName | name | area_name | domestic_competition_name ])

df3 = df3[~df3.eq('---').all(axis=1)]
df3.columns = df3.iloc[0]  # La primera fila se convierte en nombres de columna
df3 = df3[1:]
# Resetea el índice
df3.reset_index(drop=True, inplace=True)

print(df3)
# Out:
# 0                club                      liga            pais   wyId  \
# 0    Inhulets Petrove  Ukrainian Premier League         Ucrania  37291
# 1               Minaj  Ukrainian Premier League         Ucrania  62921
# 2           Rukh Lviv  Ukrainian Premier League         Ucrania  38304
# 3             Al Ahli          Saudi Pro League  Arabia Saudita  16465
# 4          Al Ettifaq          Saudi Pro League  Arabia Saudita  16468
# ..                ...                       ...             ...    ...
# 250               AIK               Allsvenskan          Suecia   6716
# 251    Brommapojkarna               Allsvenskan          Suecia   6725
# 252       Djurgardens               Allsvenskan          Suecia   6713
# 253          Elfsborg               Allsvenskan          Suecia   6721
# 254              GAIS               Allsvenskan          Suecia   6732
#
# 0              officialName                    name     area_name  \
# 0    Sdyushor Mykolayiv U17  Sdyushor Mykolayiv U17       Ukraine
# 1                  FK Minaj                FK Minaj       Ukraine
# 2              FC Rukh Lviv            FC Rukh Lviv       Ukraine
# 3       Al Ahli SC (Jeddah)     Al Ahli SC (Jeddah)  Saudi Arabia
# 4    Al Ettifaq FC (Dammam)  Al Ettifaq FC (Dammam)  Saudi Arabia
# ..                      ...                     ...           ...
# 250                     AIK             AIK Fotboll        Sweden
# 251          Brommapojkarna       IF Brommapojkarna        Sweden
# 252              Djurgården          Djurgårdens IF        Sweden
# 253                Elfsborg             IF Elfsborg        Sweden
# 254                    GAIS                    GAIS        Sweden
#
# 0   domestic_competition_name
# 0
# 1                 Persha Liga
# 2                 VBET League
# 3                  Pro League
# 4                  Pro League
# ..                        ...
# 250               Allsvenskan
# 251               Allsvenskan
# 252               Allsvenskan
# 253               Allsvenskan
# 254               Allsvenskan
#
# [255 rows x 8 columns]

# %% [markdown]
# subo a BQ

# %%
# Especifica tu ID de proyecto
project_id = 'ldp-data-wyscout'

# Crear un cliente de BigQuery con el proyecto especificado
client = bigquery.Client(project=project_id)

# Especificar la tabla de destino en el formato dataset.tabla
table_id = 'ldp-data-wyscout.capology.teamidcapology'

# Configurar la carga de datos
job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,  # Reemplaza la tabla si ya existe
)

# Guardar el DataFrame en BigQuery
job = client.load_table_from_dataframe(df3, table_id, job_config=job_config)
job.result()  # Esperar a que el trabajo termine

print(f"Los datos han sido cargados en la tabla {table_id}.")
# Out:
# Los datos han sido cargados en la tabla ldp-data-wyscout.capology.teamidcapology.

# %%
prompt0 = f"""Sos un agente que analiza datos necesito que generes una tabla con la union de la informacion de dos tablas, a partir del analisis de estas 2 tablas.
La primera tabla contiene las columnas club, liga, pais de 570 clubes y la segunda tabla contiene las columnas wyId, officialName,name, area_name y domestic_competition_name con 28425 valores. Lo que yo necesito que hagas es, encontrar las coincidencias
entre todos los valores de las columnas y a partir de esas coincidencias obtener el valor del id en el campo "wyId" de la segunda tabla
estas son las tablas: {dftext} y {dftext2}.
Es decir solamente tienen que quedar en el resultado, los valores que coinciden dentro de las dos tablas con su ID, deberian ser la misma cantidad de valores que la tabla inicial es decir 570. La tabla resultado tiene que tener todos los campos.
Las coincidencias de no se exactas pueden ser parciales, por ejemplo aclaraciones:
El campo name u officialName con club, puede ser que en club el contenido se mas abreviado, pero si encontramos la palabra que coincide es valido.
El campo pais con area_name, tiene como diferencia el idioma asique puede ser que la coincidencia sea en otro idioma.
El campo liga, esta completo en la primera tabla, pero en la segunda no siempre esta completo.
La prioridad seria encontrar la coincidencia en el nombre del club, luego para continuar el match, que coincida con el pais o area_name, luego con la liga o domestic_competition.
y los que no se encuentra coincidencias, aclararlo tambien.
Es importante tener en cuenta que lo que queremos lograr con esto es obtener el wyId de la segunda tabla para que nos provea informacion a la primera tabla, en la cual no lo tenemos.
   """
# Generar la respuesta utilizando el prompt actualizado
responses0 = model.generate_content(prompt0, generation_config=generation_config, stream=True)

# Inicializar una variable para almacenar el resultado completo
full_response0 = ""

# Recopilar y unir todas las partes de la respuesta
for responses0 in responses0:
    full_response0 += responses0.text

# Imprimir o usar la respuesta completa almacenada en la variable
print(full_response0)
# Out:
# Entiendo perfectamente lo que necesitas. Para generar la tabla con la unión de la información de las dos tablas, necesito analizar cada fila de la primera tabla y buscar la coincidencia en la segunda tabla, teniendo en cuenta las prioridades que has establecido.
#
# **Aquí te presento un ejemplo de cómo se podría estructurar la tabla resultante:**
# | Roma | Serie A | Italia | 3158 | AS Roma | Roma | Italy | Serie A | Europe |
# | Torino | Serie A | Italia | 3185 | Torino FC | Torino | Italy | Serie A | Europe |
# | Udinese | Serie A | Italia | 3163 | Udinese Calcio | Udinese | Italy | Serie A | Europe |
# | Venezia | Serie A | Italia | 3191 | Venezia Football Club | Venezia | Italy | Serie A | Europe |
# | ... | ... | ... | ... | ... | ... | ... | ... | ... |
#
# **Explicación del proceso:**
#
# 1. **Coincidencia por nombre del club:** Se busca la coincidencia exacta o parcial del nombre del club en la primera tabla con los campos "name" u "officialName" de la segunda tabla.
# 2. **Coincidencia por país:** Si no se encuentra una coincidencia exacta en el nombre del club, se busca una coincidencia entre el campo "País" de la primera tabla y el campo "area_name" de la segunda tabla. Se debe tener en cuenta que los nombres de los países pueden estar en diferentes idiomas.
# 3. **Coincidencia por liga:** Si no se encuentra una coincidencia en el nombre del club o el país, se busca una coincidencia entre el campo "Liga" de la primera tabla y el campo "domestic_competition_name" de la segunda tabla. Se debe tener en cuenta que la liga en la segunda tabla puede estar incompleta.
# 4. **No se encuentra coincidencia:** Si no se encuentra ninguna coincidencia en los tres pasos anteriores, se debe indicar en la tabla resultante que no se encontró una coincidencia para ese club.
#
# **Herramientas para la unión de tablas:**
#
# * **SQL:** Si las tablas están en una base de datos, se puede utilizar una consulta SQL JOIN para unir las tablas.
# * **Python:** Se puede utilizar la librería Pandas para leer las tablas, realizar la búsqueda de coincidencias y generar la tabla resultante.
# * **Excel:** Se puede utilizar la función BUSCARV para buscar coincidencias entre las dos tablas.
#
# **Recomendaciones:**
#
# * **Limpieza de datos:** Es importante limpiar los datos de ambas tablas antes de realizar la unión. Esto incluye eliminar espacios en blanco, convertir los nombres a un formato consistente y corregir errores ortográficos.
# * **Uso de herramientas de análisis de datos:** Se pueden utilizar herramientas de análisis de datos como Tableau o Power BI para visualizar los resultados de la unión de tablas y obtener información adicional.
#
# **Recuerda que este es un ejemplo general. El proceso específico para unir las tablas dependerá de la estructura de los datos y las herramientas que se utilicen.**

# %%
matches = re.findall(r'\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|\s*(.*?)\s*\|', full_response2)

# Convierte los datos en un DataFrame de pandas y asigna las columnas correctamente
df4 = pd.DataFrame(matches)#, columns=[club | liga | pais | wyId | officialName | name | area_name | domestic_competition_name ])

df4 = df4[~df4.eq('---').all(axis=1)]
df4.columns = df4.iloc[0]  # La primera fila se convierte en nombres de columna
df4 = df4[1:]
# Resetea el índice
df4.reset_index(drop=True, inplace=True)

print(df4)

# %%
# Especifica tu ID de proyecto
project_id = 'ldp-data-wyscout'

# Crear un cliente de BigQuery con el proyecto especificado
client = bigquery.Client(project=project_id)

# Especificar la tabla de destino en el formato dataset.tabla
table_id = 'ldp-data-wyscout.capology.2teamidcapology'

# Configurar la carga de datos
job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,  # Reemplaza la tabla si ya existe
)

# Guardar el DataFrame en BigQuery
job = client.load_table_from_dataframe(df4, table_id, job_config=job_config)
job.result()  # Esperar a que el trabajo termine

print(f"Los datos han sido cargados en la tabla {table_id}.")
# Out:
# Los datos han sido cargados en la tabla ldp-data-wyscout.capology.2teamidcapology.

# %%
# Supongamos que tus tablas están en archivos CSV
#df1 = pd.read_csv('tabla1.csv')
#df2 = pd.read_csv('tabla2.csv')

# Normalizar los nombres en ambas tablas
df1['club'] = df1['club'].str.lower().str.strip()
df1['liga'] = df1['liga'].str.lower().str.strip()
df1['pais'] = df1['pais'].str.lower().str.strip()
df1['region'] = df1['region'].str.lower().str.strip()

df2['name'] = df2['name'].str.lower().str.strip()
df2['officialName'] = df2['officialName'].str.lower().str.strip()
df2['domestic_competition_name'] = df2['domestic_competition_name'].str.lower().str.strip()
df2['area_name'] = df2['area_name'].str.lower().str.strip()
df2['region'] = df2['region'].str.lower().str.strip()

# Función para encontrar la mejor coincidencia en una lista
def get_best_match(value, choices):
    match, score = process.extractOne(value, choices, scorer=fuzz.token_sort_ratio)
    return match if score >= 80 else None

# Encontrar el ID de los clubes en la segunda tabla
df1['wyId'] = df1['club'].apply(lambda x: get_best_match(x, df2['name'].tolist()))

# Merge basado en la columna 'wyId' para obtener la información completa
merged_df = pd.merge(df, df2, left_on='wyId', right_on='name', how='inner', suffixes=('_tabla1', '_tabla2'))

# Filtrar columnas y organizar el DataFrame final
final_columns = [
    'region_tabla1', 'pais_tabla1', 'liga_tabla1', 'club_tabla1', 
    'weeklyavg', 'annualavg', 'moneda', 'wyId', 'name', 
    'officialName', 'area_name', 'domestic_competition_name', 'region_tabla2'
]
final_df = merged_df[final_columns]

# Renombrar columnas para claridad
final_df.columns = [
    'region', 'pais', 'liga', 'club', 
    'weeklyavg', 'annualavg', 'moneda', 'wyId', 'name', 
    'officialName', 'area_name', 'domestic_competition_name', 'region'
]

# Guardar o imprimir el DataFrame final
final_df.to_csv('tabla_combinada.csv', index=False)
print(final_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 37
#      31 # Filtrar columnas y organizar el DataFrame final
#      32 final_columns = [
#      33     'region_tabla1', 'pais_tabla1', 'liga_tabla1', 'club_tabla1',
#      34     'weeklyavg', 'annualavg', 'moneda', 'wyId', 'name',
#      35     'officialName', 'area_name', 'domestic_competition_name', 'region_tabla2'
#      36 ]
# ---> 37 final_df = merged_df[final_columns]
#      39 # Renombrar columnas para claridad
#      40 final_df.columns = [
#      41     'region', 'pais', 'liga', 'club',
#      42     'weeklyavg', 'annualavg', 'moneda', 'wyId', 'name',
#      43     'officialName', 'area_name', 'domestic_competition_name', 'region'
#      44 ]
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['pais_tabla1', 'liga_tabla1', 'club_tabla1', 'wyId'] not in index"

# %%
# Verifica los nombres de las columnas en merged_df
print(merged_df.columns)
# Out:
# Index(['region_tabla1', 'pais', 'liga', 'club', 'weeklyavg', 'annualavg',
#        'moneda', 'wyId_tabla1', 'wyId_tabla2', 'name', 'officialName',
#        'area_name', 'domestic_competition_name', 'region_tabla2'],
#       dtype='object')

# %% [markdown]
# UNION DE DF CON LOS PAISES EN INGLES DE LA TABLA SALARIOS_COPY CON DICT TEAMS USANDO FUZZY----

# %%
# Normalizar los nombres en ambas tablas
df22['club'] = df22['club'].str.lower().str.strip()
df22['liga'] = df22['liga'].str.lower().str.strip()
df22['pais'] = df22['pais'].str.lower().str.strip()
df22['region'] = df22['region'].str.lower().str.strip()

df2['name'] = df2['name'].str.lower().str.strip()
df2['officialName'] = df2['officialName'].str.lower().str.strip()
df2['domestic_competition_name'] = df2['domestic_competition_name'].str.lower().str.strip()
df2['area_name'] = df2['area_name'].str.lower().str.strip()
df2['region'] = df2['region'].str.lower().str.strip()

# Función para encontrar la mejor coincidencia en una lista
def get_best_match(value, choices):
    match, score = process.extractOne(value, choices, scorer=fuzz.token_sort_ratio)
    return match if score >= 60 else None

# Encontrar el ID de los clubes en la segunda tabla
df22['wyId'] = df22['club'].apply(lambda x: get_best_match(x, df2['name'].tolist()))

# Mapear los nombres encontrados a los IDs reales en df2
name_to_wyId = dict(zip(df2['name'], df2['wyId']))
df22['wyId'] = df22['wyId'].map(name_to_wyId)

# Merge basado en la columna 'wyId' para obtener la información completa
merged_df = pd.merge(df22, df2, left_on='wyId', right_on='wyId', how='inner', suffixes=('_tabla1', '_tabla2'))

# Verifica cómo se ve el merge
print(merged_df[['club', 'wyId', 'name', 'officialName']].head(10))

# Filtrar columnas y organizar el DataFrame final
final_columns2 = [
    'region_tabla1', 'pais', 'liga', 'club', 
    'weeklyavg', 'annualavg', 'moneda', 'wyId', 'name', 
    'officialName', 'area_name', 'domestic_competition_name', 'region_tabla2'
]

# Asegúrate de que las columnas existen en el DataFrame
missing_columns = [col for col in final_columns2 if col not in merged_df.columns]
if missing_columns:
    print(f"Missing columns: {missing_columns}")

# Seleccionar solo las columnas presentes en merged_df
final_columns2_existing = [col for col in final_columns2 if col in merged_df.columns]
final_df2 = merged_df[final_columns2_existing]

# Renombrar columnas para claridad
final_df2.rename(columns={
    'region_tabla1': 'region',
    'pais': 'pais',
    'liga': 'liga',
    'club': 'club',
    'weeklyavg': 'weeklyavg',
    'annualavg': 'annualavg',
    'moneda': 'moneda',
    'wyId': 'wyId',
    'name': 'name',
    'officialName': 'officialName',
    'area_name': 'area_name',
    'domestic_competition_name': 'domestic_competition_name',
    'region_tabla2': 'region'
}, inplace=True)

# Guardar o imprimir el DataFrame final
final_df2.to_csv('tabla_combinada.csv', index=False)
print(final_df2)
# Out:
#                    club   wyId                 name  \
# 0                  lafc    100                  afc
# 1          orlando city   8068         orlando city
# 2          nashville sc  30149         nashville sc
# 3             dc united   7852            dc united
# 4         new york city  32556        new york city
# 5  sporting kansas city  35493      sporting canamy
# 6    philadelphia union   8061   philadelphia union
# 7                austin  58325            blaustein
# 8   vancouver whitecaps  15015  vancouver whitecaps
# 9         fc cincinnati  37892           cincinnati
#
#                   officialName
# 0  amsterdamsche football club
# 1              orlando city sc
# 2                 nashville sc
# 3                    dc united
# 4             new york city fc
# 5         club sporting canamy
# 6           philadelphia union
# 7                tsv blaustein
# 8       vancouver whitecaps fc
# 9                fc cincinnati
#                     region           pais         liga           club  \
# 0    central/north america  united states          mls           lafc
# 1    central/north america  united states          mls   orlando city
# 2    central/north america  united states          mls   nashville sc
# 3    central/north america  united states          mls      dc united
# 4    central/north america  united states          mls  new york city
# ..                     ...            ...          ...            ...
# 565                 europe        denmark  superligaen    midtjylland
# 566                 europe        denmark  superligaen    sonderjyske
# 567                 europe        denmark  superligaen    sonderjyske
# 568                 europe        denmark  superligaen  nordsjaelland
# 569                 europe        denmark  superligaen  nordsjaelland
#
#      weeklyavg  annualavg   moneda   wyId           name  \
# 0         9330     485154  dolares    100            afc
# 1         8178     425248  dolares   8068   orlando city
# 2        11651     605862  dolares  30149   nashville sc
# 3         9577     498012  dolares   7852      dc united
# 4         8512     442640  dolares  32556  new york city
# ..         ...        ...      ...    ...            ...
# 565       6274     326250    euros   7455    midtjylland
# 566         62       3214    euros   7499    sønderjyske
# 567         62       3214    euros   7499    sønderjyske
# 568       3830     199167    euros   7458   nordsjælland
# 569       3830     199167    euros   7458   nordsjælland
#
#                     officialName      area_name domestic_competition_name  \
# 0    amsterdamsche football club    netherlands            tweede divisie
# 1                orlando city sc  united states                       mls
# 2                   nashville sc  united states                       mls
# 3                      dc united  united states                       mls
# 4               new york city fc  united states                       mls
# ..                           ...            ...                       ...
# 565               fc midtjylland        denmark                 superliga
# 566                  sønderjyske        denmark                 superliga
# 567                  sønderjyske        denmark                 superliga
# 568              fc nordsjælland        denmark                 superliga
# 569              fc nordsjælland        denmark                 superliga
#
#                     region
# 0                europe eu
# 1    central/north america
# 2    central/north america
# 3    central/north america
# 4    central/north america
# ..                     ...
# 565              europe eu
# 566              europe eu
# 567              europe eu
# 568              europe eu
# 569              europe eu
#
# [570 rows x 13 columns]

# %%
# Renombrar columnas duplicadas sino me da error al intentar subirlo a BQ
final_df2.columns = [
    'region_tabla1','pais','liga','club', 
    'weeklyavg', 'annualavg', 'moneda', 'wyId', 'name', 
    'officialName', 'area_name','domestic_competition_name' ,'region_tabla2'
]

# %%
from google.cloud import bigquery

# Especifica tu ID de proyecto
project_id = 'ldp-data-wyscout'

# Crear un cliente de BigQuery con el proyecto especificado
client = bigquery.Client(project=project_id)

# Especificar la tabla de destino en el formato dataset.tabla
table_id = 'ldp-data-wyscout.capology.fuzzy2'

# Configurar la carga de datos
job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,  # Reemplaza la tabla si ya existe
)

# Guardar el DataFrame en BigQuery
job = client.load_table_from_dataframe(final_df2, table_id, job_config=job_config)
job.result()  # Esperar a que el trabajo termine

print(f"Los datos han sido cargados en la tabla {table_id}.")
# Out:
# Los datos han sido cargados en la tabla ldp-data-wyscout.capology.fuzzy2.

# %% [markdown]
# sin liga

# %%
df22['club'] = df22['club'].str.lower().str.strip()
df22['pais'] = df22['pais'].str.lower().str.strip()
df22['region'] = df22['region'].str.lower().str.strip()

df2['name'] = df2['name'].str.lower().str.strip()
df2['officialName'] = df2['officialName'].str.lower().str.strip()
df2['area_name'] = df2['area_name'].str.lower().str.strip()
df2['region'] = df2['region'].str.lower().str.strip()

# Función para encontrar la mejor coincidencia en una lista
def get_best_match(value, choices):
    match, score = process.extractOne(value, choices, scorer=fuzz.token_sort_ratio)
    return match if score >= 70 else None

# Encontrar el ID de los clubes en la segunda tabla
df22['wyId'] = df22['club'].apply(lambda x: get_best_match(x, df2['name'].tolist()))

# Mapear los nombres encontrados a los IDs reales en df2
name_to_wyId = dict(zip(df2['name'], df2['wyId']))
df22['wyId'] = df22['wyId'].map(name_to_wyId)

# Merge basado en la columna 'wyId' para obtener la información completa
merged_df = pd.merge(df22, df2, on='wyId', how='inner', suffixes=('_tabla1', '_tabla2'))

# Verifica cómo se ve el merge
print(merged_df[['club', 'wyId', 'name', 'officialName']].head(10))

# Filtrar columnas y organizar el DataFrame final
final_columns2 = [
    'region_tabla1', 'pais', 'club', 
    'weeklyavg', 'annualavg', 'moneda', 'wyId', 'name', 
    'officialName', 'area_name', 'region_tabla2'
]

# Asegúrate de que las columnas existen en el DataFrame
missing_columns = [col for col in final_columns2 if col not in merged_df.columns]
if missing_columns:
    print(f"Missing columns: {missing_columns}")

# Seleccionar solo las columnas presentes en merged_df
final_columns2_existing = [col for col in final_columns2 if col in merged_df.columns]
final_df2 = merged_df[final_columns2_existing]

# Renombrar columnas para claridad
final_df2.rename(columns={
    'region_tabla1': 'region',
    'pais': 'pais',
    'club': 'club',
    'weeklyavg': 'weeklyavg',
    'annualavg': 'annualavg',
    'moneda': 'moneda',
    'wyId': 'wyId',
    'name': 'name',
    'officialName': 'officialName',
    'area_name': 'area_name',
    'region_tabla2': 'region'
}, inplace=True)

# Guardar o imprimir el DataFrame final
final_df2.to_csv('tabla_combinada.csv', index=False)
print(final_df2)
# Out:
#                    club     wyId                 name  \
# 0                  lafc    100.0                  afc
# 1          orlando city   8068.0         orlando city
# 2          nashville sc  30149.0         nashville sc
# 3             dc united   7852.0            dc united
# 4         new york city  32556.0        new york city
# 5  sporting kansas city  35493.0      sporting canamy
# 6    philadelphia union   8061.0   philadelphia union
# 7                austin  58325.0            blaustein
# 8   vancouver whitecaps  15015.0  vancouver whitecaps
# 9         fc cincinnati  37892.0           cincinnati
#
#                   officialName
# 0  amsterdamsche football club
# 1              orlando city sc
# 2                 nashville sc
# 3                    dc united
# 4             new york city fc
# 5         club sporting canamy
# 6           philadelphia union
# 7                tsv blaustein
# 8       vancouver whitecaps fc
# 9                fc cincinnati
#                     region           pais           club  weeklyavg  \
# 0    central/north america  united states           lafc       9330
# 1    central/north america  united states   orlando city       8178
# 2    central/north america  united states   nashville sc      11651
# 3    central/north america  united states      dc united       9577
# 4    central/north america  united states  new york city       8512
# ..                     ...            ...            ...        ...
# 545                 europe        denmark    midtjylland       6274
# 546                 europe        denmark    sonderjyske         62
# 547                 europe        denmark    sonderjyske         62
# 548                 europe        denmark  nordsjaelland       3830
# 549                 europe        denmark  nordsjaelland       3830
#
#      annualavg   moneda     wyId           name                 officialName  \
# 0       485154  dolares    100.0            afc  amsterdamsche football club
# 1       425248  dolares   8068.0   orlando city              orlando city sc
# 2       605862  dolares  30149.0   nashville sc                 nashville sc
# 3       498012  dolares   7852.0      dc united                    dc united
# 4       442640  dolares  32556.0  new york city             new york city fc
# ..         ...      ...      ...            ...                          ...
# 545     326250    euros   7455.0    midtjylland               fc midtjylland
# 546       3214    euros   7499.0    sønderjyske                  sønderjyske
# 547       3214    euros   7499.0    sønderjyske                  sønderjyske
# 548     199167    euros   7458.0   nordsjælland              fc nordsjælland
# 549     199167    euros   7458.0   nordsjælland              fc nordsjælland
#
#          area_name                 region
# 0      netherlands              europe eu
# 1    united states  central/north america
# 2    united states  central/north america
# 3    united states  central/north america
# 4    united states  central/north america
# ..             ...                    ...
# 545        denmark              europe eu
# 546        denmark              europe eu
# 547        denmark              europe eu
# 548        denmark              europe eu
# 549        denmark              europe eu
#
# [550 rows x 11 columns]
# C:\Users\flori\AppData\Local\Temp\ipykernel_23592\771867300.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df2.rename(columns={

# %%
# Renombrar columnas duplicadas sino me da error al intentar subirlo a BQ
final_df2.columns = [
    'region_tabla1', 'pais','club', 
    'weeklyavg', 'annualavg', 'moneda', 'wyId', 'name', 
    'officialName', 'area_name', 'region_tabla2'
]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 2
#       1 # Renombrar columnas duplicadas sino me da error al intentar subirlo a BQ
# ----> 2 final_df2.columns = [
#       3     'region_tabla1','pais','liga','club',
#       4     'weeklyavg', 'annualavg', 'moneda', 'wyId', 'name',
#       5     'officialName', 'area_name','domestic_competition_name' ,'region_tabla2'
#       6 ]
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File c:\Users\flori\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 11 elements, new values have 13 elements

# %%
from fuzzywuzzy import process, fuzz
import pandas as pd

# Normalizar las columnas
df22['club'] = df22['club'].str.lower().str.strip()
df22['pais'] = df22['pais'].str.lower().str.strip()
df22['region'] = df22['region'].str.lower().str.strip()

df2['name'] = df2['name'].str.lower().str.strip()
df2['officialName'] = df2['officialName'].str.lower().str.strip()
df2['area_name'] = df2['area_name'].str.lower().str.strip()
df2['region'] = df2['region'].str.lower().str.strip()

# Función para encontrar la mejor coincidencia
def get_best_match(value, choices):
    match, score = process.extractOne(value, choices, scorer=fuzz.token_sort_ratio)
    return match if score >= 80 else None

# Inicializar una lista para almacenar los IDs
df22['wyId'] = None

# Priorizar los matchings
for column in ['club', 'pais', 'region']:
    if column == 'club':
        df22['wyId'] = df22['club'].apply(lambda x: get_best_match(x, df2['name'].tolist()))
    elif column == 'pais':
        # Solo buscar si no hay match en club
        df22.loc[df22['wyId'].isnull(), 'wyId'] = df22.loc[df22['wyId'].isnull(), 'pais'].apply(
            lambda x: get_best_match(x, df2['area_name'].tolist())
        )
    elif column == 'region':
        # Solo buscar si no hay match en pais
        df22.loc[df22['wyId'].isnull(), 'wyId'] = df22.loc[df22['wyId'].isnull(), 'region'].apply(
            lambda x: get_best_match(x, df2['region'].tolist())
        )

# Mapear los nombres encontrados a los IDs reales en df2
name_to_wyId = dict(zip(df2['name'], df2['wyId']))
df22['wyId'] = df22['wyId'].map(name_to_wyId)

# Merge basado en la columna 'wyId'
merged_df = pd.merge(df22, df2, on='wyId', how='inner', suffixes=('_tabla1', '_tabla2'))

# Verifica cómo se ve el merge
print(merged_df[['club', 'wyId', 'name', 'officialName']].head(10))

# Filtrar columnas y organizar el DataFrame final
final_columns2 = [
    'region_tabla1', 'pais', 'club', 
    'weeklyavg', 'annualavg', 'moneda', 'wyId', 'name', 
    'officialName', 'area_name', 'region_tabla2'
]

# Asegúrate de que las columnas existen en el DataFrame
missing_columns = [col for col in final_columns2 if col not in merged_df.columns]
if missing_columns:
    print(f"Missing columns: {missing_columns}")

# Seleccionar solo las columnas presentes en merged_df
final_columns2_existing = [col for col in final_columns2 if col in merged_df.columns]
final_df2 = merged_df[final_columns2_existing]

# Renombrar columnas para claridad
final_df2.rename(columns={
    'region_tabla1': 'region',
    'pais': 'pais',
    'club': 'club',
    'weeklyavg': 'weeklyavg',
    'annualavg': 'annualavg',
    'moneda': 'moneda',
    'wyId': 'wyId',
    'name': 'name',
    'officialName': 'officialName',
    'area_name': 'area_name',
    'region_tabla2': 'region'
}, inplace=True)

# Guardar o imprimir el DataFrame final
final_df2.to_csv('tabla_combinada.csv', index=False)
print(final_df2)
# Out:
#                    club   wyId                 name  \
# 0                  lafc    100                  afc
# 1          orlando city   8068         orlando city
# 2          nashville sc  30149         nashville sc
# 3             dc united   7852            dc united
# 4         new york city  32556        new york city
# 5  sporting kansas city   8134        united states
# 6    philadelphia union   8061   philadelphia union
# 7                austin  58325            blaustein
# 8   vancouver whitecaps  15015  vancouver whitecaps
# 9         fc cincinnati  37892           cincinnati
#
#                   officialName
# 0  amsterdamsche football club
# 1              orlando city sc
# 2                 nashville sc
# 3                    dc united
# 4             new york city fc
# 5                united states
# 6           philadelphia union
# 7                tsv blaustein
# 8       vancouver whitecaps fc
# 9                fc cincinnati
#                     region           pais           club  weeklyavg  \
# 0    central/north america  united states           lafc       9330
# 1    central/north america  united states   orlando city       8178
# 2    central/north america  united states   nashville sc      11651
# 3    central/north america  united states      dc united       9577
# 4    central/north america  united states  new york city       8512
# ..                     ...            ...            ...        ...
# 565                 europe        denmark    midtjylland       6274
# 566                 europe        denmark    sonderjyske         62
# 567                 europe        denmark    sonderjyske         62
# 568                 europe        denmark  nordsjaelland       3830
# 569                 europe        denmark  nordsjaelland       3830
#
#      annualavg   moneda   wyId           name                 officialName  \
# 0       485154  dolares    100            afc  amsterdamsche football club
# 1       425248  dolares   8068   orlando city              orlando city sc
# 2       605862  dolares  30149   nashville sc                 nashville sc
# 3       498012  dolares   7852      dc united                    dc united
# 4       442640  dolares  32556  new york city             new york city fc
# ..         ...      ...    ...            ...                          ...
# 565     326250    euros   7455    midtjylland               fc midtjylland
# 566       3214    euros   7499    sønderjyske                  sønderjyske
# 567       3214    euros   7499    sønderjyske                  sønderjyske
# 568     199167    euros   7458   nordsjælland              fc nordsjælland
# 569     199167    euros   7458   nordsjælland              fc nordsjælland
#
#          area_name                 region
# 0      netherlands              europe eu
# 1    united states  central/north america
# 2    united states  central/north america
# 3    united states  central/north america
# 4    united states  central/north america
# ..             ...                    ...
# 565        denmark              europe eu
# 566        denmark              europe eu
# 567        denmark              europe eu
# 568        denmark              europe eu
# 569        denmark              europe eu
#
# [570 rows x 11 columns]
# C:\Users\flori\AppData\Local\Temp\ipykernel_23592\738396499.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df2.rename(columns={

# %%
from google.cloud import bigquery

# Especifica tu ID de proyecto
project_id = 'ldp-data-wyscout'

# Crear un cliente de BigQuery con el proyecto especificado
client = bigquery.Client(project=project_id)

# Especificar la tabla de destino en el formato dataset.tabla
table_id = 'ldp-data-wyscout.capology.fuzzy'

# Configurar la carga de datos
job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,  # Reemplaza la tabla si ya existe
)

# Guardar el DataFrame en BigQuery
job = client.load_table_from_dataframe(final_df2, table_id, job_config=job_config)
job.result()  # Esperar a que el trabajo termine

print(f"Los datos han sido cargados en la tabla {table_id}.")
# Out:
# Los datos han sido cargados en la tabla ldp-data-wyscout.capology.fuzzy.
